# %%
    import json
    import facebook
    import requests

    def get_basic_info(graph):


        profile = graph.get_object('me',fields='first_name,last_name,location,link,email')	

        print(json.dumps(profile, indent=5))

    def get_all_posts(graph):

        posts = graph.request('/me/posts')
        count=1
        while "paging" in posts: 
            print("length of the dictionary",len(posts))
            print("length of the data part",len(posts['data']))
            for post in posts["data"]:
                print(count,"\n")
                if "message" in post:
                    print(post["message"])
                print("time :  ",post["created_time"])
                print("id   :",post["id"],"\n\n")
                count=count+1

            #post2=graph.request(posts["paging"]["next"])
            posts=requests.get(posts["paging"]["next"]).json()
            
        print("end of posts")
            
    
    def authentication():
        
        f = open("token.txt", "r")
        f1=[]
        for x in f:
            f1.append(x.rstrip())
        token=f1[0]
        graph = facebook.GraphAPI(token)
        return graph
        
    def main():

        graph=authentication()
        
        #get_basic_info(graph)
        get_all_posts(graph)



    if __name__ == '__main__':

        main()
# Out:
# length of the dictionary 2
# length of the data part 25
# 1
#
# Sammy is still my hero :v
# that part with De bruijn graph and shift registers though :o
#
#
# time :   2020-02-18T12:15:03+0000
# id   : 3964403643573572_3964348203579116
#
#
# 2
#
# Pertinent to today's visit.
#
# time :   2020-02-12T15:26:31+0000
# id   : 3964403643573572_3944744905539446
#
#
# 3
#
# Bangladesh - have wickets in hand, just need to play big shots and score runs quickly.
#
# Plan A: go down the ground and swing the bat blindly as hard as you can.
# Plan B : try to scoop the ball behind the wicket and look stupid.
# Plan C: .....
# Gets out :v
# time :   2019-11-07T14:46:02+0000
# id   : 3964403643573572_3620587927955147
#
#
# 4
#
# "say my name.
# say my name."
# :3
# time :   2019-11-03T16:59:09+0000
# id   : 3964403643573572_3608001322547141
#
#
# 5
#
# thank you Tabia Binte Farazi 😊
# time :   2019-11-02T15:23:05+0000
# id   : 3964403643573572_3604516472895626
#
#
# 6
#
# বন্ধু Gifarie Tayeef Islam একটা গোলাপি কম্বল গায়ে মুড়িয়ে হলে মরার মত ঘুমিয়ে ছিল। তার রুমমেট সেটার ছবি তুলে ডে দিয়েছিল, আর ক্যাপশন দিয়েছিল "RIP gifarie"। কিছুক্ষণ পর মজা পেয়ে অনেক ডাক্তার বন্ধুরাই একই ছবি একই ক্যাপশনে ডে দিতে থাকে।
# একটু পর শুরু হয় অঘটন। অনেকে আসলেই ভাবা শুরু করে গিফারী মরে গেছে। জুনিয়ররা কান্না শুরু করে দেয়, খোঁজ নিতে থাকে, " আপু,কিভাবে হল? :( " টাইপ ম্যাসেজ আসা শুরু হয়।
#
# এরপর থেকে যদি আর কেউ বলিস যে "friends" এর প্লট রিয়েলিস্টিক না 😂
# আর গিফারী বেঁচে আছে, সুস্থ আছে, সবার দুয়া চেয়েছে সে। ঢাকায় আসলে সবাই কে ট্রিট দিবে বলেছে।
# time :   2019-10-25T15:47:42+0000
# id   : 3964403643573572_3577797085567565
#
#
# 7
#
# ব্যাপারটা এখন এমন হয়ে গেছে যে, "জোকার মুভিটা ভাল লাগে নাই" বললে "তার মানে তুই বুঝস নাই" টাইপ প্রতিউত্তর পাবেন।
# time :   2019-10-25T15:27:08+0000
# id   : 3964403643573572_3577742525573021
#
#
# 8
#
# "আশ্চর্য, মেয়েটা রেগে গেল কেন?"
#
# #মঞ্চ_নাটক
# #আজ_রবিবার
# #পৌনঃপুনিক_১৫_ব্যাচ_প্রোগ্রাম
# time :   2019-10-23T12:58:20+0000
# id   : 3964403643573572_3571251856222088
#
#
# 9
#
# বুয়েটের একটার পর একটা ভয়ংকর সত্য ঘটনা পড়তেসি গত ৫ দিন ধরে।
# নিজেকে এত clueless, এত বোকা, এত দীন দুনিয়ায় বাইরে কখনো মনে হয় নাই।
# #Dumbstrucked  :)
# time :   2019-10-14T12:18:59+0000
# id   : 3964403643573572_3542200109127263
#
#
# 10
#
# A movie from my childhood.
# Perfect metaphor for the metamorphosis that has taken place in BUET.
#
#
# time :   2019-10-09T15:57:54+0000
# id   : 3964403643573572_3527423360604938
#
#
# 11
#
# প্রতি পিএল এই সবচেয়ে সহজ আর ছোট সিলেবাস এর সাবজেক্টটা দিয়ে পড়া শুরু করি।
# ১-২ দিন পড়ার পর অনুধাবন করি যে সাবজেক্টটা বেশ কঠিন আর সিলেবাস বিশাল।
# :3
# time :   2019-10-04T17:10:11+0000
# id   : 3964403643573572_3512616638752277
#
#
# 12
#
# শাশ্বত সৌম্য : guys i made a group study schedule. have a look 😍
# Abdullah Al Ishtiaq : কালকে ব্যাংকে কাজ আছে, কালকে বাদ দে।
# Sadia Tasnim :এত দূর থেকে আবার কালকে আসব এই গরমের মধ্যে। এর চেয়ে অন্যদিন পড়া।
# me : এতক্ষণ ধরে কি পড়বি? আমি কালকে আসতে পারব কিনা শিউর না...
#  Awsaf Alam : ভাই কালকে অফিস আছে, বাসায় কাজ আছে, অন্যদিন কর।
# Rituparna Datta : সৌম্য, আমাকে একদম শুরু থেকে বুঝায় দিয়ো কিন্তু...
# Jamalia Sultana Jisha : seenzones
#  Afsara Benazir : compiles this status :v
# time :   2019-09-23T16:55:07+0000
# id   : 3964403643573572_3479963515350923
#
#
# 13
#
# ব্যস্ততার কি আর শেষ আছে...
# 😂
# p.c. শাশ্বত সৌম্য
# time :   2019-09-14T18:53:20+0000
# id   : 3964403643573572_3453714844642457
#
#
# 14
#
# ব্যস্ততার শেষ আছে নাকি...
# 😂
# time :   2019-09-14T18:17:01+0000
# id   : 3964403643573572_3453640951316513
#
#
# 15
#
# interestingly this wish actually came true in BUET CSE!!!
# Even my current position is  31!!!
# almost every one of those demands came true.
# life is weird, scary weird :v
# time :   2019-09-02T16:06:46+0000
# id   : 3964403643573572_3419494374731171
#
#
# 16
#
# Man, was i surprised to see the list of speakers or what?
# Arpon Paul is giving a lecture on a seminar!!!
# Do visit him if you can .
# time :   2019-09-02T15:07:19+0000
# id   : 3964403643573572_3419351044745504
#
#
# 17
#
# মানুষ ঘুম ধরলে চা খায়, কফি খায়।
# আমি ঘুম ধরলে ঘুমায় নেই।
# time :   2019-08-26T16:45:51+0000
# id   : 3964403643573572_3399836620030280
#
#
# 18
#
# -দোস্ত,আমার hpds এর paper review টা লিখে দে, ২০০ টাকা দিব।
# - তোরে আমি ৪০০ টাকা দিব, আমার টা করে দে।
# -আমি ৬০০ দিব, আমার টা করে দে।
# -আচ্ছা যা আমি ৮০০ দিব।
# -_-
# with Tanjim Bin Faruk
# time :   2019-08-01T15:41:49+0000
# id   : 3964403643573572_3330893743591235
#
#
# 19
#
# time :   2019-07-04T10:31:39+0000
# id   : 3964403643573572_3253739227973354
#
#
# 20
#
# একই রাতে সেমির স্বপ্ন আর মেসির স্বপ্ন শেষ হয়ে গেল।
# পোলাপান এই শোক নিবে কিভাবে?
# time :   2019-07-03T03:44:47+0000
# id   : 3964403643573572_3250573758289901
#
#
# 21
#
# first deserve, then desire.
# and yeah, stop hating others for being better than you.
# time :   2019-07-02T18:04:58+0000
# id   : 3964403643573572_3249494775064466
#
#
# 22
#
# "ও, আব্বু, আজকে তো বাবা দিবস। happy father's day"
# "থ্যাংক ইউ। চুলটা কাটায় আসো, যাও"
# -_-  -_-  -_-
# time :   2019-06-16T14:23:19+0000
# id   : 3964403643573572_3203987116281899
#
#
# 23
#
# যদিও অভিমান করার মত মানুষের সংখ্যা দিন দিন কমে যাচ্ছে....
# time :   2019-06-15T15:29:05+0000
# id   : 3964403643573572_3201275066553104
#
#
# 24
#
# Eid Mubarak
# <3
# time :   2019-06-05T06:44:08+0000
# id   : 3964403643573572_3173300916017186
#
#
# 25
#
# life is getting too serious too fast.
# its fucking scary.
# :(
# time :   2019-06-03T16:49:32+0000
# id   : 3964403643573572_3169061433107801
#
#
# length of the dictionary 2
# length of the data part 25
# 26
#
# victory payesh 😄
# with Nishat Rahman
# time :   2019-06-02T19:03:36+0000
# id   : 3964403643573572_3166622150018396
#
#
# 27
#
# সেরা ইফতারি <3
# time :   2019-06-01T18:25:36+0000
# id   : 3964403643573572_3163900563623888
#
#
# 28
#
# এই ছেলেপেলেগুলার সাথে বছরে একবার আড্ডা হয়। <3
# এরপরের বছর আর আড্ডা হবে কিনা কে জানে।
# এটাই তো মনে হয় জীবনের শেষ রোজার ছুটি।
#
# edit:
# ও আচ্ছা, এইটা Afraim Al Hasan এর বাসা। :3
# ও গেসিল আমাদের জন্য আইসক্রিম আনতে। <3
# time :   2019-05-27T16:44:07+0000
# id   : 3964403643573572_3150603958286882
#
#
# 29
#
# You're only gangsta' untill the real gangsta' arrives
# শাশ্বত সৌম্য 15 slice pizza
# ami 16 slice pizza
# :p 🤣🤣
# table winner মুহাইমিনুল ইসলাম সার্থক 17.5 slice
# time :   2019-05-19T15:37:10+0000
# id   : 3964403643573572_3129750130372265
#
#
# 30
#
# thank you Ishtiaq Niloy and শাশ্বত সৌম্য for the gift <3
#
# আপুকে দেখালাম, আপু দেখে বলে,
# "আয়হায়, এইটা কি লেখা। :o
# ও আচ্ছা, তবলা!  আমি ভাবলাম... "
# 🤣🤣🤣
# time :   2019-05-14T15:19:12+0000
# id   : 3964403643573572_3116404555040156
#
#
# 31
#
# কেউ কোন একসময় তোমার উপকার করেছিল, তাই সারাজীবন তার প্রতি কৃতজ্ঞ থাকতে হবে, ভুল জিনিসেও সাপোর্ট দিয়ে যেতে হবে - ব্যাপারটা মোটেও এমন না। যথেষ্ট পরিমান কারন থাকলে উপকারী মানুষটাকেও অপছন্দ করার অধিকার তোমার আছে। সে উপকার করেছে, মাথা কিনে নেয় নাই।
# কিন্তু তুমি যদি নিজের সুবিধা বুঝে কাকে কখন অপছন্দ করবে সেটা ঠিক কর,তবে তোমার মাঝেও সমস্যা আছে। আজকে তাকে দরকার, তাই তার সাথে খাতির জমিয়ে রাখলে, দরকার ফুরিয়ে যাবার কিছুদিন পরই তাকে অপছন্দ করা শুরু করলে - যথেষ্ট কারন থাকলেও এই আচরন প্রশ্নবিদ্ধ।
# time :   2019-05-12T18:40:52+0000
# id   : 3964403643573572_3111663758847569
#
#
# 32
#
# অনেক প্রিয় একটি ছবি। নষ্ট হয়ে যাবে ভেবে লেমিনেটিং করে রেখেছিলাম। আজ জানতে পারলাম আমি বিদেশে থাকার সময় কেউ কেজি দরে এটি বিক্রি করে দিয়েছে। সেই সাথে আমার ছোটবেলার যত জিনিদ আছে সব। নিজেকে এতটা নিঃস্ব কখনও লাগে নি এর আগে।
# time :   2019-04-28T17:28:46+0000
# id   : 3964403643573572_3077080558972556
#
#
# 33
#
# Our hult prize journey came to an end. We gave our best but sadly we couldn’t win. I really thought we had a good chance to win this thing. Perhaps that's why the results were severely disappointing to me.
# But nevertheless, i am proud to have the chance to represent BUET in an international event. I expect to learn and grow from this experience and do new things.
# The biggest thing i realised throughout our journey is how helpful and amazing our seniors are! So many of them helped us in so many ways!
# Mahin Ahmed vaiya mentored us like a elder brother.Without his guidelines, our project wouldn’t be possible.
# Buet Alumni Association funded our trip, made our life very easy early on.
# There were 3 teams from buet participating in hult prize and all of us were able to fund our trip because of our seniors. Javed Ikbal vai, Jewel Julkernine vai,Jakaria Jalal vai, Sabbir Ahmed Emon vai, জাহাঙ্গীর আলম vai, Mohammad Abu Taiob vai, Masud Karim Khan vai, @israt meherin joya apu and so many other unnamed seniors helped us directly! Without them, our pilot project wouldn’t be possible. its just sad that we disappointed all of you :(
#  Mustafa Rafid has helped us out in every situation we had. from crowd funding to changing regions, he has been a constant support for us. He even used to send us inspirational messages :p
# Joyee Chakma Joy and Arju, previous campus winners shared their experience with us. We learned a lot from them. we would love to share our experience with the next years team. i believe they will fulfill what we couldn’t do and bring the cup for BUET. 😊
# Forgive me if i missed anyone.
# I'll be ending this status with a personal realisation. A competitive person like me always loses to a passionate person. So i have decided to use the last year of my University life to try to find my passion. Please pray for me so that i can find it.
# #hult_Prize
# #signing_off
# time :   2019-04-26T16:39:59+0000
# id   : 3964403643573572_3072046919475920
#
#
# 34
#
# আর্টিফিশিয়াল ইন্টেলিজেন্স পরীক্ষা দিয়ে  নিজের ইন্টেলিজেন্সকেই আর্টিফিশিয়াল মনে হচ্ছে...
# time :   2019-04-06T13:47:50+0000
# id   : 3964403643573572_3024363537577592
#
#
# 35
#
# One day i will be telling my kids about Arpon Paul.
# How he used to be in my class and how he outclassed us all.
#
# He has been selected for summer student program  of CERN!!!
# <3 <3 <3
# He will go to Switzerland this summer.
# <3
# time :   2019-03-26T15:01:30+0000
# id   : 3964403643573572_2998478906832722
#
#
# 36
#
# awww....
# <3
# happy birthday to Rudmila
# time :   2019-03-22T18:40:49+0000
# id   : 3964403643573572_2989818357698777
#
#
# 37
#
# it's amazing how easily this can be prepared!!!
# time :   2019-03-01T06:14:42+0000
# id   : 3964403643573572_2943685078978772
#
#
# 38
#
# নগদ যা পাও হাত পেতে নাও
# বাকির খাতা শুন্য থাক,
# দুরের বাদ্য লাভ কি শুনে
# মাঝখানে তো বেজায় ফাঁক।
#
# -ওমর খৈয়াম
# time :   2019-02-28T14:06:26+0000
# id   : 3964403643573572_2942182322462381
#
#
# 39
#
# Who is the most famous mathematician of all time?
# A lot of people will say, it's Srinivasa Ramanujan.
# well, what is the most famous math problem?
# The answer probably is 'Fermat's Last Theorem'.
# These are probably the most common answers to these questions.
# But did you know, Ramanujan actually attempted to prove Fermat's last theorem?!!!
# Yes, he did. And before you get excited Ramanujan-fanboys,
# sadly, No! He couldn't prove the Fermat's last theorem.
#
# But he did go unimaginably close!!! He started to use elliptic curves to solve this problem. And this is what Andrew Wiles used to prove the theorem in 1994.
# And yes, elliptic curves wasn't a developed field in Ramanujan's time. He literally invented a lot of it to prove the theorem!
# He also invented K3 surface and a general equation of near misses of fermate's last theorem in this process.
# So even though his attempts ended in failure, it was a huge success for mathematics itself.
# time :   2019-02-25T13:40:43+0000
# id   : 3964403643573572_2935193579827922
#
#
# 40
#
# তখন মাত্র বুয়েটের ক্লাস শুরু হয়েছে। অন্যান্য ভার্সিটির বন্ধুদের নানান রকম গল্প শুনে কি ভয় পেয়েই না ঢুকেছিলাম ক্লাসে। ক্লাস শেষে একঝাক ভাইয়া আপু ক্লাসে ঢুকলেন। বললেন, তোমাদের সাথে কথা আছে, বস। এই বুঝি র‍্যাগ খেলাম! এসে উনারা সবার আগেই বললেন, এই তোমরা এত ভয় পাচ্ছ কেন? ভয় এর কিছু নেই।
# সত্যি সেদিন বুঝতে পারলাম ভয় এর কিছু নেই। অসাধারণ বন্ধুত্বপূর্ণ একটা সিনিয় ব্যাচ পেয়েছি আমরা।
#
# ক্যাম্পাসে সিনিয়র জুনিয়র সম্পর্ককে ভালবাসার সম্পর্কে পরিনত করতে সিএসই ১৪ ছিল পথিকৃৎ।
# অনেকদিনের বিরতির পর,আবারও নবীনবরনের আয়োজন করে নৈবদ্য ১৪।আর আমরা সেই সৌভাগ্যবান নবীন,যাদের তারা বরন করেছিল।
# সকল দুঃসময়ে পাশে থেকেছিল সিএসই ১৪।ড্রাইভ এর লিনক, কোড, আইডিয়া কি চাই নাই আমরা!
# আমরা একসাথে হেসেছি, কেদেছি, নেচেছি গেয়েছি, কাজ করেছি। সব সময় মনে হয়েছে আমাদের উপর ছায়া হয়ে দাড়িয়ে আছে ১৪। সেই ছায়াটা আর কিছুদিন পর চলে যাবে।
# আর কিছুদিন পর নাকি আমরা র‍্যাগ ব্যাচ!!!
# কি অদ্ভুত! কি অদ্ভুত!!!
# time :   2019-02-08T14:41:25+0000
# id   : 3964403643573572_2894539420560005
#
#
# 41
#
# i kept playing until i got Charizard :3
# time :   2019-01-12T20:11:27+0000
# id   : 3964403643573572_2835519063128708
#
#
# 42
#
# because reality sucks
# time :   2019-01-03T17:10:14+0000
# id   : 3964403643573572_2815989795081635
#
#
# 43
#
# অনেক দিন পর ট্রেনভ্রমন আর নৌকাভ্রমন হল গত পরশুদিন। সিভিল ডিপার্টমেন্টের বিশাল আকারের দল যাবে BAU, মাঝে দিয়ে আমিও ঢুকে পড়লাম অতিথি হিসেবে।মধ্য রাতে (!) ঘুম থেকে উঠে পৌছে গেলাম কমলাপুরে।ট্রেনে উঠে দেখি এত পুরো স্কুল-কলেজের পিকনিক এর আবহ!
#
# এর আগ পর্যন্ত আমার ট্রেন ভ্রমনগুলো কেটেছে ট্রেনের চানাচুর খেতে খেতে আর বাইরের গরুর সংখ্যা গুনতে গুনতে। আর আজ কাটল গানের কলি খেলতে খেলতে আর মন খুলে বেসুরো গলায় গান গাইতে গাইতে। <3
#
# সেখানে পৌছে উঠলাম নৌকায়, শীতের শান্ত নদীতে সুরের পসরা সাজিয়ে বসল আমাদের সুমিষ্ট গলার গায়িকারা। কি অদ্ভুত সে মুহূর্ত!
#
# সব জায়গায় গিয়ে আমার প্রাইজ নিয়ে আসার ব্যাপারটা আজকাল রীতিমত জোক্সে পরিণত হয়েছে।এই পিকনিকও বাদ যাবে কেন? পিলো পাসিং আর ব্যালান্স রেস এ হেরে যাওয়ার পরও, র‍্যাফেল ড্র তে গ্রান্ড প্রাইজটা আমিই পেয়ে গেলাম :p বিভিন্ন জায়গায় প্রাইজ পাওয়ার পেছনে যে ভাগ্যই মূল ভুমিকা রাখে, তারই এক সূক্ষ্ম ইংগিতই বুঝি পেয়ে গেলাম :3
#
# যারা ইতিমধ্যে ট্রিট চাওয়ার কথা ভাবা শুরু করেছিস,তাদের বলি, পুরষ্কার হিসেবে আমি পেয়েছি ২ কেজি ফ্রেশ ময়মনসিংহের মুলা!  সিভিলের পিকনিকে সত্যি সত্যি মুলা ঝুলিয়ে দিল আমাকে তাহলে 😂
# যাই হোক,রাতে সে মুলা খেয়ে আব্বু বলেছেন, মুলাটা অনেক ফ্রেশ।  <3
#
# রাতের ট্রেনে ফেরার পথে ট্রেনের চানাচুর খেয়ে ভ্রমনের ষোলো কলা পূর্ণ হল।
#
# Atika মেয়েটা জীবনে অনেক প্যারা দিসে, কিন্তু এই ট্যুরে তার অর্গানাইজিং কেপাবিলিটি দেখে আমি মুগ্ধ।সবাইকে নিজের এলাকা ঘুরিয়েছে অংকুর অন্তু, সাথে সুন্দর সুন্দর ছবিও তুলে দিয়েছে।
#
# আমাকে নিজেদের মানুষ বানিয়ে ফেলায় সিভিল এর সবাইকে অসংখ্য ধন্যবাদ।  একগাদা নতুন বন্ধু বানিয়ে ফেলেছি আমি।  <3
# time :   2018-12-21T16:15:51+0000
# id   : 3964403643573572_2787998191214129
#
#
# 44
#
# Projecting a fake image of your personality in social media 101....
# p.c. :  অংকুর অন্তু
# time :   2018-12-20T16:55:12+0000
# id   : 3964403643573572_2786004114746870
#
#
# 45
#
# the muddy water in the back might look ugly, but this is also where you are safe.
# the blue water behind it, you might get lost in there.
# thanks to Sakib Al Razi Khan 😁
# time :   2018-12-09T04:27:14+0000
# id   : 3964403643573572_2319174008096552
#
#
# 46
#
# hai vondura kmn lagsa bloto.. :*
# Nadia Anjum Antara অনুমতি নিয়ে ফ্রেপ করেছিল।
# অতি উচ্চমানের ফ্রেপ :v
# time :   2018-12-09T04:22:27+0000
# id   : 3964403643573572_2761557790524836
#
#
# 47
#
# We won the hult prize buet 2019!!!
#
# Winning the Hult prize was in my bucket list since 1-1. The idea of representing buet in an international competition really gives me the chills.
#
# Its been a great journey so far <3
#
# The regionals might be held on Malaysia,Singapore  or Dubai.Not sure which one we would attend. I will keep you guys updated.
#
# Also i will get good pictures by tomorrow. Until then, its the best i have :v
# time :   2018-12-06T17:13:54+0000
# id   : 3964403643573572_2756338084380140
#
#
# 48
#
# You are the only person who understood me in my toughest time.
# happy birthday Khala
# <3
# time :   2018-11-30T18:24:07+0000
# id   : 3964403643573572_2743183765695572
#
#
# 49
#
# "আশ্চর্য, মেয়েটা রেগে গেল কেন?"
#
# #মঞ্চ_নাটক
# #আজ_রবিবার
# #পৌনঃপুনিক_১৫_ব্যাচ_প্রোগ্রাম
# time :   2018-11-26T15:23:11+0000
# id   : 3964403643573572_2734578439889438
#
#
# 50
#
# We won the GDG Hack sprint winter!!!
# more of an idea contest :p
# we might also get an full time paid internship offer from toggy  services limited.
# but probably won't be  able to join them because of academic pressure.  :(
# Keep us in the prayers <3
# time :   2018-11-25T15:22:00+0000
# id   : 3964403643573572_2732589770088305
# length of the dictionary 2
# length of the data part 25
# 51
#
# time :   2018-11-16T09:27:05+0000
# id   : 3964403643573572_2713920731955209
#
#
# 52
#
# time :   2018-09-29T09:38:09+0000
# id   : 3964403643573572_2613813751965908
#
#
# 53
#
# #Help_online_sohopathi
# #To_conquer_Berlin
# জাতিসংঘের অঙ্গ সংগঠন UNESCO আর জার্মানীভিত্তিক একটি প্রতিষ্ঠান Stiftung Entreprenuership আয়োজিত আন্তর্জাতিক প্রতিযোগিতা "Youth Citizen Entrepreneurship Competition-2018" প্রতিযোগিতায় সারা বিশ্ব থেকে সেরা ৫০ টি উদ্যোগ এর একটি হিসেবে নির্বাচিত হয়েছে আমাদের Online Sohopathi - অনলাইন সহপাঠী। সবচেয়ে গর্বের ব্যাপার হচ্ছে, বাংলাদেশ থেকে মাত্র দুটি উদ্যোগ নির্বাচিত হয়েছে সেরা ৫০ এর মাঝে। এখান থেকে সেরা ১০ টি উদ্যোগ নির্বাচিত হবে অক্টোবরে জার্মানির বার্লিনে হতে চলা চূড়ান্ত পর্বের জন্য।
#
# মজার ব্যাপার হচ্ছে, সেরা ১০ নির্বাচিত হবে পুরোপুরি ভোট আর কমেন্টের ভিত্তিতে। সবার কাছে "অনলাইন সহপাঠী"র একজন co-founder হয়ে একটাই অনুরোধ Help us to reach Berlin ! ভোট দেয়ার আর দুই দিন আছে মাত্র । ভোট দেয়ার নিয়ম প্রথম comment এ
# time :   2018-08-13T16:01:42+0000
# id   : 3964403643573572_2522279877785963
#
#
# 54
#
# Resolution of the day:
#
# accept the failure, relax and listen to the sound of the music...
# time :   2018-07-29T15:40:05+0000
# id   : 3964403643573572_2488687174478567
#
#
# 55
#
# time :   2018-07-22T14:36:39+0000
# id   : 3964403643573572_2473498905997394
#
#
# 56
#
# when friends from other departments try to say that they have too much pressure on 3-1.
# :3
# time :   2018-07-18T18:39:05+0000
# id   : 3964403643573572_2465233076823977
#
#
# 57
#
# নিজের ভালোটা আসলে নিজেই বুঝতে হয়। অন্য কেউ সেটা বুঝবে না.....
# time :   2018-07-09T15:54:46+0000
# id   : 3964403643573572_2446004145413537
#
#
# 58
#
# My classmates vs me
# :v
# time :   2018-07-04T19:24:25+0000
# id   : 3964403643573572_2435269139820371
#
#
# 59
#
# ছেলে দুটোকে স্বান্তনা দেই।
# :(
# time :   2018-06-30T15:35:10+0000
# id   : 3964403643573572_2426191057394846
#
#
# 60
#
# প্লাস্টিক সাপোর্টার হিসেবে আমার এখন কাকে সাপোর্ট করা উচিৎ বন্ধুরা?
# ব্রাজিল, স্পেন নাকি ফ্রান্স?
# :3
# time :   2018-06-27T16:00:41+0000
# id   : 3964403643573572_2420166307997321
#
#
# 61
#
# some people are always there when you need them.
# but they are never around you when you don't particularly 'need' them.
# thus they may become you're savior but never become your friend.
# time :   2018-06-27T13:15:54+0000
# id   : 3964403643573572_2419882064692412
#
#
# 62
#
# we fight till the end.
# till the end...
# <3
# time :   2018-06-23T19:54:31+0000
# id   : 3964403643573572_2412428165437802
#
#
# 63
#
# 7 years later,nothing has changed...
# :)
# time :   2018-06-23T15:01:56+0000
# id   : 3964403643573572_2411982178815734
#
#
# 64
#
# আজ ২২জুন উত্তর গোলার্ধের সবচেয়ে ছোট রাতগুলোর একটি।
# কিন্তু আর্জেন্টাইন ফ্যানদের আজ রাতটা অনেক বড় লাগবে।
# time :   2018-06-21T19:51:41+0000
# id   : 3964403643573572_2408267032520582
#
#
# 65
#
# জার্মানির সাপোর্টারদের আসলে পচায়ে তেমন মজা পাবে না। এদের বেশিরভাগই যুক্তিতে চলে,আবেগে না(যাকে সবাই প্লাস্টিক বলে আর কি)।
#
# বেশিরভাগ জার্মানির সাপোর্টারস দের থ্রেডে দেখলাম কেন জার্মানি হারল সেটা নিয়ে এনালাইসিস চলছে।কেন ফরমেশনটা ঠিক হয় নি,  কেন ক্রুসকে সঠিকভাবে ব্যবহার করা হয় নি, মিডফিল্ড কিভাবে ডিফেন্সকে সাপোর্ট দিতে ব্যর্থ হয়েছে ইত্যাদি ইত্যাদি।
#
# কাউকে তেমন কাঁদতে বা গালাগালি করতে দেখলাম না।
#  তাই পচানিতে কারও তেমন যায় আসার কথা না।
#
# আর সবচেয়ে বড় কথা, ব্রাজিল ড্র করেছে, সেটা তো জার্মানির হারার থেকেও বড় খবর। ;)
# time :   2018-06-17T20:37:00+0000
# id   : 3964403643573572_2400233239990628
#
#
# 66
#
# আইসল্যান্ড ও সুইজারল্যান্ড এর মধ্যে কোন দলটি অধিক শক্তিশালী, সেটা নিয়ে দীর্ঘ আলোচনা আসন্ন।
# #proxywar_is_on
# 😂
# time :   2018-06-17T20:04:07+0000
# id   : 3964403643573572_2400185723328713
#
#
# 67
#
# পেনালদো হওয়ার জন্যও যোগ্যতা লাগে।
# time :   2018-06-16T16:30:41+0000
# id   : 3964403643573572_2397784626902156
#
#
# 68
#
# A6
# after two years.
# so many memories <3
# with Shadman Islam Mf Imtiaz Imtiaz Ahmed Sunny Akash Ibna Habib
# time :   2018-06-07T15:48:20+0000
# id   : 3964403643573572_2382099051804047
#
#
# 69
#
# গত একবছর যে ভাল কোন হ্যাংআউট হয় নাই,তার প্রমাণ এই ছবি। গতবার যেই ছবি দিয়ে উইশ করসিলাম, এইবারও সেই ছবি দিয়েই উইশ করতেসি।
# -_-
# যাই হোক, শুভ জন্মদিন Hasin Ar Rafi bro.
# ভাল থাক, সুখে থাক, সুখবর লুকায়ে রাখিস না :p
# time :   2018-05-31T10:07:13+0000
# id   : 3964403643573572_2371239709556648
#
#
# 70
#
# গতকালও যে আপনার কাচ্চি বিরিয়ানির আলু ছিল, আজ হয়ে যাবে এলাচি।
# জীবনটা এমনই...
# 😂
# time :   2018-05-30T13:57:24+0000
# id   : 3964403643573572_2370057729674846
#
#
# 71
#
# Wasting time has it's own unique feeling. you do enjoy yourself a lot, but there is a little feeling of guilt hiding in the background. they both mix and create a unique state of mind where you know you aren't gonna be free before 2 hours,but you keep looking at the clock anyway.
# time :   2018-05-29T17:33:58+0000
# id   : 3964403643573572_2368949373119015
#
#
# 72
#
# on public demand.
# with শাশ্বত সৌম্য
# when the weed hits the spot...
# time :   2018-05-23T16:22:00+0000
# id   : 3964403643573572_2360033087343977
#
#
# 73
#
# probably the "hello world" of micro-controllers?
# took almost 4 hours just to do that :(
# made almost dozens of mistakes.also, one of the atmega32 was broken.
# lesson learned? yeah,  its gonna be hard to pass this lab :(
# time :   2018-05-17T17:28:30+0000
# id   : 3964403643573572_2351527728194513
#
#
# 74
#
# "এমন একটা বাক্য বলতে পারবা,যেটা শুনতে আনন্দের মনে হয় কিন্তু তার গভীরে বিষাদ লুকানো আছে?"
# "কেন পারব না? এই যেমন,
#   "পেজপাড়িয়া রাজকুমারী গলায় চন্দ্রহার,
#     দিনে দিনে বাড়ছে তোমার চুলেরই বাহার""
# time :   2018-05-11T13:30:36+0000
# id   : 3964403643573572_2342632039084082
#
#
# 75
#
# time :   2018-05-10T05:17:11+0000
# id   : 3964403643573572_2340705669276719
#
#
# length of the dictionary 2
# length of the data part 25
# 76
#
# thanks to Naimul Arefin
# time :   2018-05-08T18:59:26+0000
# id   : 3964403643573572_2338727409474545
#
#
# 77
#
# 😂
# never thought about it this way 😂
# time :   2018-05-05T14:11:43+0000
# id   : 3964403643573572_2333849453295674
#
#
# 78
#
# "পুত্র‍্যাৎ শিষ্যাৎ পরাজয়ে গৌরবের হানি হয় না জানি। কিন্তু যাহাকে মাত্র কয়দিন আগে হাতে ধরিয়া দাবার চাল দিতে শিখাইয়াছি,তাহার কাছে হারিয়া গেলে নিজের বুদ্ধিবৃত্তির উপর সন্দেহ হয়।আমার চিত্তে আর সুখ রহিল না।"
#
# (চিড়িয়াখানা)
# -শরদিন্দু বন্দোপাধ্যায়
# time :   2018-05-02T13:18:07+0000
# id   : 3964403643573572_2329343513746268
#
#
# 79
#
# I feel pity for the people with high IQ but low EQ.
# They are able to charm people around them quickly but disappoint everyone in the long run.
# time :   2018-04-29T17:46:16+0000
# id   : 3964403643573572_2325294057484547
#
#
# 80
#
# if any of you are added to this profile, please remove it.
# report if you can.
# someone created a fake account.
# I don't know what's wrong with people these days.
# please check the id in the first comment.
#
# this guy probably blocked me, so I cant post the id link in the post :v
# time :   2018-04-23T14:22:03+0000
# id   : 3964403643573572_2316298968384056
#
#
# 81
#
# happy birthday dost
# time :   2018-04-15T14:21:49+0000
# id   : 3964403643573572_2304718149542138
#
#
# 82
#
# রিয়াপু!!!
# আমাকে এক জীবনে তুই ভদ্র ছেলে ভাবতি, সেটা ভাবতেই হাসি পায়। আশা করি আমাকে আর ডিচ না করে, রিক্সা ভাড়া বাঁচাতে সাহায্য করবি :v
# শুভ জন্মদিন।
# with Saima Hoque Ria
# time :   2018-04-06T18:21:21+0000
# id   : 3964403643573572_2291138930900060
#
#
# 83
#
# after a totally unproductive day, with no work done, what's the best thing you can do?
# just visualize your day and try to eliminate the causes...
# time :   2018-04-01T16:35:13+0000
# id   : 3964403643573572_2282943908386229
#
#
# 84
#
# " তোমাদের পড়াশোনা হওয়া উচিৎ OBE বা outcome based education
# কিন্তু ইদানিং এটা হয়ে যাচ্ছে IBE মানে income based education."
# #ক্লাসরুম_ফিলোসফি
# time :   2018-03-31T16:17:42+0000
# id   : 3964403643573572_2281407598539860
#
#
# 85
#
# ব্যাপারটা আগেও বলেছি, আবারও বলছি,
#
# "আমাদের দেশের পর্যটন বা ট্যুরিজম এ কোন সেফটি বা নিরাপত্তা নাই।"
#
# সেফটি মানে এটা না যে কোন দূর্ঘটনা ঘটবে না। এটা পুরোপুরি নিশ্চিত করা সম্ভব না।
# সেফটি মানে হল, যদি কোন দূর্ঘটনা ঘটে তবে যেন আমাদের প্রাণহানি না ঘটে, মানুষগুলোকে যেন বাচাঁন যায়।
# এদেশে এমন ব্যবস্থা খুব একটা দেখা যায় না। যখনই একটা দূর্ঘটনা ঘটে, কেউ না কেউ মারা যায়। :(
#
# আমি বেশি ট্যুর দেই নাই, এত বেশি জানিও না। কিন্তু নিজের চোখে যাই দেখসি, তাই বেশ অনিরাপদ লাগসে। আলুটিলায় যে কেউ পিছলা খেয়ে পড়ে যেতে পারত,মাথা ফেটে যেতে পারত, রেসাং ঝড়নায় স্লাইড দিতে গিয়ে যে জামা কাপড় ছিড়ে যেতে পারে,ব্যাথা পেতে পারে এইগুলা কোথাও লেখাই ছিল না, খাগড়াছড়ি পাহাড়ের মাঝে দিয়ে যাওয়ার সময় যে কেউ পিছলা খেয়ে পড়ে যেতে পারত, ধরার কেউ ছিল না, সুন্দরবনে নৌকা ডুবে যেতে পারত।
#
# কিন্তু সমস্যাটা শুধু ব্যবস্থাপনায় সীমাবদ্ধ না। আমাদেরও একটা বড় সমস্যা আছে। আমাদের মধ্যে সেফটি বিরোধী একটা মনোভাব তৈরী হয়েছে, কেন হয়েছে জানি না।
#
# শেষ সুন্দরবন ট্যুর এর কথাই যদি বলি, আমি সিদ্ধান্ত নিলাম, পানিতে যেহেতু যাচ্ছি, লাইফ জ্যাকেট কিনি। মজার কথা হল, বেশ কয়েকজন আমাকে বলসে, "কি দরকার কিনার, কাজে লাগবে না, খামাখা টানতে হবে"। তাও আমি কিনলাম। মাওয়াঘাটে পৌছে ট্রলারে উঠার সময় আমি যখন লাইফ জ্যাকেট পড়া শুরু করলাম, তখন কেউ একজন জোরে জোরে বলা শুরু করল, "ওই দেখ, এখনি পড়ে ফেলতেসে"। দুবলার চর এ গিয়ে সেফটি রেঞ্জার যখন আমাদের সবাইকে ডাকলেন নিরাপত্তা বিষয়ে কিছু বলতে, তখন কেউ কেউ ২ বার ডাকার পরও আসল না। তারা বীচ এ নাচানাচি করতে ব্যস্ত। লঞ্চ থেকে ডাঙায় যাওয়ার সময় একটা নৌকা করে যেতাম আমরা, সেখানে ওঠার সময় দেখি একটা মানুষও লাইফ জ্যাকেট পড়ে নাই। সবাইকে দেখে আমিও পড়লাম না আর সেটা!!!  ফিরে আসার সময় একবার অনেক স্রোত শুরু হল, নৌকা কাঁপতে লাগল। সেবার যদি নৌকাটা ডুবে যাইত, তাহলে আমি নিশ্চিত মারা যেতাম। আমি একা না, সবাই।
# এক বন্ধু তার গল্প শুনাল, কিভাবে সে সিলেটে প্রায় মরতে মরতে বেচেঁ গেছে। গল্পের মূল কথা হল, সে সাঁতার জানে না, ঝড়নার নিচের পানিতে নামসিল, পানির চাপে ডুবে যাচ্ছিল, কেউ একজন ধাক্কা দিয়ে তাকে সরাইসে। এই গল্প শুনে সবাই অভিভূত হয়ে গেল। কেউ মনে হয় অন্য আরেকটা কাহিনী শুনে তার সাহসের প্রশংসা করা শুরু করল। সাহসিকতা আর বোকামির পার্থক্য হয়ত আমরা ভুলে যেতে বসেছি। :)
#
# কোথাও ঘুরতে গেলে, যে সেফটি নিয়ে বেশি কথা বলে, সে "ভীতু" এর ট্যাগ পেয়ে যায়। অথচ, সাঁতার না জেনে পানিতে নামলে সে বোকা না হয়ে সাহসী হয়ে যায়।
#
# অনেক হয়েছে, এবার সময় হয়েছে, "বুয়েটিয়ানদের সাথে পানির সর্ম্পক খারাপ"- এই কথাটা শুধু মুখে নয়, অন্তরে প্রবেশ করানোর, কাজে তার প্রতিফলন ঘটানোর। :)
# time :   2018-03-24T15:21:42+0000
# id   : 3964403643573572_2269429289737691
#
#
# 86
#
# হিমু সমগ্রে আপনি কোন কাহিনী নাই খুঁজে পেতে পারেন, মিসির আলীর গল্পগুলো পড়ে অতিপ্রাকৃত মনে হতে পারে;বোতল ভুত পড়ে হয়ত আপনার হাসি পায় নি; বৃষ্টিবিলাস বা মৃন্ময়ীর মাঝে হয়ত আপনি অসাধারণ কিছু খুঁজে পান নি।
# কিন্তু শুধু এক জোছনা ও জননীর গল্পের জন্য আপনার হুমায়ূন আহমেদ কে ধন্যবাদ দিতেই হবে।
# <3
# time :   2018-03-23T14:06:01+0000
# id   : 3964403643573572_2267772063236747
#
#
# 87
#
# lame selfie it is 😎
# time :   2018-03-20T15:44:26+0000
# id   : 3964403643573572_2263281490352471
#
#
# 88
#
# I am lucky to have this safe corner in the room of my mind.
# time :   2018-03-17T15:45:47+0000
# id   : 3964403643573572_2258440427503244
#
#
# 89
#
# কাকে বেছে নেবেন?
# যে আপনার কথা শুনে ঘুমিয়ে পড়ে,
# নাকি যে আপনার সাথে কথা বলে ঘুমাতে পারে না?
# time :   2018-03-17T12:25:12+0000
# id   : 3964403643573572_2258147180865902
#
#
# 90
#
# ট্রলারের ইঞ্জিনের বিকট শব্দে এক অদ্ভুত রকমের নিস্তব্ধতা আছে।
# time :   2018-03-12T18:57:34+0000
# id   : 3964403643573572_2250271551653465
#
#
# 91
#
# happy birthday Ishtiaq Niloy 😁
# time :   2018-03-01T15:23:51+0000
# id   : 3964403643573572_2232244416789512
#
#
# 92
#
# পাস ফেল আল্লাহ এর হাতে,
# কিন্তু theory of computation আমার পড়া এ পর্যন্ত সবচেয়ে মজার সাবজেক্ট।
# <3
# time :   2018-02-21T12:59:37+0000
# id   : 3964403643573572_2219912808022673
#
#
# 93
#
# :3
# time :   2018-02-20T15:21:25+0000
# id   : 3964403643573572_2218541464826474
#
#
# 94
#
# happy birthday Zahin Wahab bro
# time :   2018-02-11T18:42:09+0000
# id   : 3964403643573572_2205212979492656
#
#
# 95
#
# আহারে পচু...
# feeling sad with Sadia Tasnim
# sad reacts only
# time :   2018-02-09T17:44:38+0000
# id   : 3964403643573572_2202260093121278
#
#
# 96
#
# এক্সামের আগে সাদা দেয়ালের দিকে তাকায় থাকতেও ভাল্লাগে।
# পোকেমন গেম তো সেখানে স্বর্গীয়...
# 😒
# time :   2018-02-08T18:00:15+0000
# id   : 3964403643573572_2200789556601665
#
#
# 97
#
# ফেক ক্যান্ডিড তোলার চেষ্টা করে বেশি সুবিধা হচ্ছিল না। পরে স্যুট এর বোতামটা খুলে সত্যি সত্যি বোতাম লাগানো শুরু করলাম...
# p.c. শাশ্বত সৌম্য
# time :   2018-02-06T14:49:11+0000
# id   : 3964403643573572_2197869826893638
#
#
# 98
#
# when the tree leaves dance,one shall find flames.
# the fire shadow will illuminate the village...
# <3
# time :   2018-02-04T19:01:25+0000
# id   : 3964403643573572_2195384980475456
#
#
# 99
#
# happy birthday Rituparna Datta 😎
# time :   2018-02-02T05:18:52+0000
# id   : 3964403643573572_2191721824175105
#
#
# 100
#
# সূর্যগ্রহন প্রচন্ড আকর্ষনীয় একটি জিনিস। দিনের মাঝে রাতের মত অন্ধকার হয়ে যাচ্ছে, তাপমাত্রা কমে যাচ্ছে,পাখিরা নীড়ে ফিরে যাচ্ছে, দিনের আকাশে রাতের তারা দেখা যাচ্ছে-চিন্তা করলেই একটা রোমাঞ্চ অনুভব করি।
#
# সে তুলনায় চন্দ্রগ্রহণ একেবারেই সাদামাটা। আজ সারাদিন ফেসবুকে চন্দ্রগ্রহণ নিয়ে এত আলোচনা না হলে, এই ব্যস্ত শহরের নব্বইভাগ মানুষ টের ও পেত না যে আজ একটা চন্দ্রগ্রহন হয়ে গিয়েছে।
#
# অথচ এই চন্দ্রগ্রহন দেখেই আদিম মানুষ প্রথম উপলব্ধি করে যে পৃথিবী গোল। কারন চাঁদের উপর পড়া পৃথিবীর ছায়াটাও যে গোল!!!
# প্রাচীন গ্রীকরা এই চন্দ্রগ্রহনের স্থায়িত্বকাল থেকে হিসেব করে দেখিয়েছিল যে পৃথিবী চাঁদের থেকে প্রায় ৫০ গুন বড়!
#
# রাতের আকাশ শুধু রহস্যময়ই নয়, বিভিন্ন রহস্যভেদ করতেও এর অবদান অনেক।
# time :   2018-01-31T16:06:58+0000
# id   : 3964403643573572_2189548011059153
# length of the dictionary 2
# length of the data part 25
# 101
#
# -I guess it's just not my day.
# -is it about the day? what does the solar system has to do with your day? you are sad because of your actions and probably because of people around you.
# time :   2018-01-31T14:26:36+0000
# id   : 3964403643573572_2189424334404854
#
#
# 102
#
# or the name you used for that email :3
# with Ishtiaq Niloy Sadia Tasnim শাশ্বত সৌম্য Awsaf Alam Anindo
# time :   2018-01-31T12:55:51+0000
# id   : 3964403643573572_2189314914415796
#
#
# 103
#
# thanks to #buet_brainiacs <3
# time :   2018-01-27T12:52:39+0000
# id   : 3964403643573572_2183239395023348
#
#
# 104
#
# when you desperately want to find something interesting and end up forgetting you're basics
# 😂
# time :   2018-01-23T13:44:12+0000
# id   : 3964403643573572_2177160902297864
#
#
# 105
#
# তোমার সাথে আমার প্রথম দেখা, খুব সাধারন একটা পরিচয় পর্ব, হাজারো পরিচিত মানুষের মধ্যে নতুন একটা মানুষ যোগ হওয়া- হ্যা খুব সাধারন আমাদের প্রথম দেখার গল্প।
# একদিন কোমল গলার গান শুনে,পেন্সিলে আকাঁ ছবি দেখে আর প্রাণ খুলে গল্প করে না হয় একটু ভাল লেগেই গিয়েছিল। কিন্তু তখনও কি আমি বুঝেছি তুমি কতটা গুরুত্বপূর্ণ হয়ে উঠবে আমার জীবনে?
#
# ধীরে ধীরে আপন হয়ে ওঠার খুব সাধারণ গল্প আমাদের। ফেসবুকের চ্যাটফ্রেন্ড,তারপর বন্ধু,তারপর কাছের বন্ধু,তারপর প্রানখুলে মনের সব কথা বলার মানুষ-হ্যা, সবগুলো ধাপই যেন পাড় করেছি আমরা।
#
# কারনে-অকারনে তোমাকে বুঝিয়েছি,তুমি আমার কাছে গুরুত্বপূর্ণ একজন।সূক্ষভাবে ইংগিত দিয়ে গিয়েছি মুগ্ধতার।তবে তোমার সাথে কথা বলায়,তোমার কথা শোনায়, তোমায় চোখে চোখে রাখায় যে আমি অভ্যস্ত হয়ে গিয়েছি, সেটা হয়ত তখনো বুঝতে পারি নি।
#
# বুঝেছি যখন তোমাকে হারানোর ভয় এসেছে মনে। এরপর আর ভুল করিনি। বলে দিয়েছি সেই একমাত্র কথা যা এতদিন তোমার কাছ থেকে গোপন করে আসছিলাম। বলে দিয়েছি যে ভালবাসি।
#
# এই জানো? গতকাল সকালেও তোমাকে স্বপ্নে দেখেছি। কোন এক অজানা কারনে তোমাকে নিয়ে দেখা বেশিরভাগ স্বপ্নই ভয়ের হয়। হারিয়ে ফেলার ভয় হয়ত অবচেতন মনে বেশি জায়গা নিয়ে আছে।
# তবে গতকালের স্বপ্নটি ভাল ছিল। ঘুমের মাঝে দেখা স্বপ্ন ও সচেতন মনে জীবন নিয়ে দেখা স্বপ্ন এক হয়ে গেছে সেখানে। যেন আমার সচেতন ও অবচেতন মন সবই তোমার দখলে চলে গেছে।
#
# "মাঝে মাঝে তব দেখা পাই... " গানটিতে একটা লাইন আছে,
# "কি করিলে বল পাইব তোমারে, রাখিব আঁখিতে আঁখিতে..."
# এই লাইনটা শুনলেই তোমার চেহারা মনে ভেসে ওঠে
# জানো?
#
# তুমি একমাত্র মানুষ যার সাথে রোদের মধ্যে ২০ মিনিট রিক্সায় আটকে থাকতে খারাপ লাগে না,
#  যার সাথে গ্রাজুয়েট কম্পেক্স এ বসে কোন কথা না বলে নিজের পড়া পড়তেও শান্তি লাগে,
# প্রচন্ড রোমান্টিক মুহুর্তেও "লাইব্রেরিতে গিয়ে ম্যাটল্যাব পড়াও" শুনতেও রাগ লাগে না,বরং বসে বসে ভুলে যাওয়া ম্যাটল্যাবের ফাংশন রান করতেও মজা লাগে।
#
# এইত ভালবাসা।
#
# ছবিটা প্রতীকি,
# আমার মন খারাপের মুহূর্তে তোমার মন ভাল করে দেওয়া, সাহস দেওয়া অথবা শুধু পাশে বসে থাকা-এই জিনিস গুলো যে আমার জন্য কতটা গুরুত্বপূর্ণ আমি বোঝাতে পারব না। কারন হয়ত আমি নিজেও পুরোপুরি বুঝি না।
#
# শুভ জন্মদিন বলতে শুরু করেছিলাম, কি কি যেন বলে ফেললাম...
#
# শুভ জন্মদিন তোমায়।
# <3
# time :   2018-01-16T18:09:54+0000
# id   : 3964403643573572_2166877496659538
#
#
# 106
#
# দুনিয়ার বেশিরভাগ জিনিসের ব্যাপারেই আমার চয়েস অনেক খারাপ। তবে বন্ধু বাছাই করার ক্ষেত্রে আমার চয়েস অনেক ভাল 😎
# time :   2018-01-15T14:32:58+0000
# id   : 3964403643573572_2165248600155761
#
#
# 107
#
# শেষ পর্যন্ত চেষ্টা করে যেতে হবে।
# তাহলে হয়েও যেতে পারে।
# আর যদি নাও হয়, মনের মধ্যে চেষ্টা না করার আফসোসটা থাকবে না।
# time :   2018-01-13T19:06:12+0000
# id   : 3964403643573572_2162839920396629
#
#
# 108
#
# প্রোজেক্ট দেয়ার ১ সপ্তাহ পরে,
# স্যার: শুনো, এইটা ডাটাবেজ এর প্রোজেক্ট, ui এ সময় নষ্ট করবা না।
# প্রোজেক্ট সাবমিশনের ১ সপ্তাহ আগে,
# স্যার: তোমাদের প্রোজেক্ট টা তো user friendly হয় নাই। এমনে তো হবে না।
# -_-
# time :   2018-01-10T13:33:47+0000
# id   : 3964403643573572_2158443680836253
#
#
# 109
#
# পরম নির্ভরতায় হাসি মুখে এভাবেই জীবনের গিট্টুগুলো খুলে দিতে থাক দাদা।
# শুভ জন্মদিন।
# <3
# time :   2018-01-08T18:22:47+0000
# id   : 3964403643573572_2155780391102582
#
#
# 110
#
# my abbu is like, "you're 21? huh! At your age I was 22!!!"
# time :   2018-01-01T16:20:40+0000
# id   : 3964403643573572_2144189688928319
#
#
# 111
#
# a junior of inter 2nd year was telling me, "vai, amar je ki hbe... :(  "
# I was like, yeah,  I used to say that to myself too when I was at your age.
# oh wait, I still say that to myself :v
# time :   2017-12-31T14:43:11+0000
# id   : 3964403643573572_2142400452440576
#
#
# 112
#
# you know those situations, when you go to an expensive coffee shop, order an overpriced cup of coffee and you don't even like the taste of it.
# you say to yourself, "they served me an overpriced cup of crap".
# well, in some contexts, that "literally" happens. 😂😂😂
# introducing "kopi luwak"
# worlds most costly coffee,made from shit of wild civets.
# you need 35 to 80 dollars for buying  one cup of this coffee!!!
# time :   2017-12-27T17:23:12+0000
# id   : 3964403643573572_2137263356287619
#
#
# 113
#
# so my friend Awsaf Alam Anindo has started a new tech company. well, I always knew he would do something like that.
# who knows, maybe he is the next tech tycoon of our country. 😍
# best of luck buddy
#
# https://www.facebook.com/FingerTips-Inc-915899068566894/?notif_id=1514372737511644&notif_t=page_fan
# time :   2017-12-27T16:17:23+0000
# id   : 3964403643573572_2137200992960522
#
#
# 114
#
# "এডমিশন ভাইয়া" পেজটা খোলার পর যে পরিমাণ মানুষের কাছ থেকে আমরা উৎসাহ ও অনুপ্রেরণা পেয়েছি তা অবিশ্বাস্য।তাই সব সময়ই মনে হয়েছে কিভাবে নতুন কিছু করা যায় তোমাদের জন্য।
#
# তাই এবার আমরা সত্যি সত্যি একটা ওয়েবসাইট বানিয়ে ফেলেছি তোমাদের জন্য!!!
#
# এখানে গিয়ে বিভিন্ন প্রশ্ন করতে পারবে, প্রশ্নের উত্তর দিতে পারবে, অন্যের উত্তর দেখতে পারবে, আর সামনে আরো ফিচার তো এড করা হবেই। 😎
#
# ফেসবুক পেজ এর একটা বড় সমস্যা ছিল যে, যেকোন একটা ভাল প্রশ্ন কিছুদিন পর হারিয়ে যায়, সেটা খুজে পেতে স্ক্রল করতে করতে নিচে নামতে হয়, প্রশ্নগুলোকে ক্যাটাগোরাইজ করা যায় না।যার সব কিছুই এখানে সম্ভব। 😍
#
# আর "এডমিশন ভাইয়া" নামটা সবারই কিছুটা অপছন্দ ছিল। তাই নতুন একটা নাম দেয়া হয়েছে ওয়েবসাইট এর আর তা হল "অনলাইন সহপাঠী"।
#
# ওয়েবসাইট এর লিনক কমেন্ট এ দেয়া হল।
# go check it out.
# keep asking and answering.
# <3
# time :   2017-12-21T16:03:49+0000
# id   : 3964403643573572_2128005510546737
#
#
# 115
#
# আমার ফ্রেন্ডলিস্টে যারা স্কুল কলেজের আছো, তারা কাল চলে আসো। তোমাদের জন্যই এই ইভেন্ট। আর খাওয়াদাওয়া ত আছেই। ;)
# time :   2017-12-20T15:44:35+0000
# id   : 3964403643573572_2126619574018664
#
#
# 116
#
# শীতনিদ্রার সময় ঘনিয়ে আসছে 😍
# time :   2017-12-19T15:04:40+0000
# id   : 3964403643573572_2125247550822533
#
#
# 117
#
# inverse matrix of a 4*4 matrix.
# one can "easily" find it.
# :v
# random pages of engineering books...
# time :   2017-12-13T15:48:59+0000
# id   : 3964403643573572_2115685438445411
#
#
# 118
#
# প্রতিটা admission season যায়, আর হাজার হাজার গল্প তৈরী হয়।
# সফলতার গল্প, ব্যর্থতার গল্প,প্রতিকূলতাকে জয় করার গল্প, স্রোতের বিপরীতে চলার গল্প, ছোট ছোট ভুল থেকে বড় বিপদে পড়ে যাওয়ার গল্প, আবার হতাশা থেকে নিজেকে নিজে টেনে তোলার গল্প।
#
# সবচেয়ে বড় কথা, এই গল্পগুলো প্রচন্ড শিক্ষণীয়।
#
# সমস্যা হচ্ছে, এইসব গল্পগুলো আসলে সবার সামনে আসেই না, কিছু গল্প হয়ত ফেসবুকে শেয়ার হয় এই কয়দিন,এরপর হারিয়ে যায়।
#
# তাই একটা ইভেন্ট খুলেছি আমরা, "এডমিশনের দিনগুলো",  যেখানে নিজের গল্পটা লিখে পাঠাতে পারবেন, যা সবাই পড়তে পারবে, আর সেরা লেখার জন্য পুরস্কার তো আছেই...
#
# এখানে লেখা পাঠাতে তোমার বুয়েটেই পড়তে হবে এমন কোনই কথা নেই। নিজের গল্পটাই বেশি গুরুত্বপূর্ণ, যা শুনে ছোটরা কিছু শিখতে পারবে।
# আমার তো মনে হয়, সব গল্প থেকেই কিছু শেখার আছে। নাম প্রকাশে অনিচ্ছুক থাকলে সেটাও করা যাবে ।
# কমেন্টে ইভেন্ট এর লিনক দেয়া হল।
#
# তোমার গল্প হোক অনুজের অনুপ্রেরণা।
#
# <3
# time :   2017-12-11T16:26:01+0000
# id   : 3964403643573572_2112887422058546
#
#
# 119
#
# everyone is criticising the journalist for asking stupid questions to sofia...
# so, if u have one chance to ask something to that AI, what would the question be?
# time :   2017-12-07T17:07:56+0000
# id   : 3964403643573572_2105997869414168
#
#
# 120
#
# "সহজ সমস্যাকে সহজ বলা সহজ হলেও, কঠিন সমস্যাকে কঠিন বলা এতটা সহজ নয়।
# হয়ত আপাত কঠিন সমস্যাটির একটি সহজ সমাধান আছে যা তুমি দেখতে পাচ্ছ না"
# -ডাটাস্ট্রাকচার এন্ড অ্যালগোরিদম ক্লাস
# #classroom_philosophy
# time :   2017-12-06T14:08:03+0000
# id   : 3964403643573572_2104349822912306
#
#
# 121
#
# trying to figure out the deeper meaning of the art...
# p.c. Awsaf Alam Anindo
# time :   2017-12-03T15:20:16+0000
# id   : 3964403643573572_2100048036675818
#
#
# 122
#
# পুরো টিম এর ডস্লার মার্কা ঝকঝকে ছবি লোডিং...
# আপাতত এইটা দিয়েই কাজ চালাই :3
# #25years_celebration
# #debatathon
# #1st_runners_up
#
# বি: দ্র: পুরো 30k আমার না, ৪ জনের টিম :p
# time :   2017-12-02T16:09:56+0000
# id   : 3964403643573572_2098606996819922
#
#
# 123
#
# "Admission vaiya" এডমিশন টেস্টে লেভেল প্লেয়িং ফিল্ড গড়ে দেওয়ার উদ্দেশ্যে একটি উদ্যোগ।
#
# গত তিন মাসে আমাদের এই চেষ্টাটা এত সাড়া পাবে আমরা আশাও করি নি। শুধু লাইক সংখ্যাই নয়,ছাত্র-ছাত্রীরা পেজ রিভিও এ আমাদের তাদের ভাল-লাগা, শুভ কামনা ও ভবিষ্যৎ এ চালিয়ে যাওয়ার অনুপ্রেরণা দিয়ে গেছে। এক জুনিয়র তার ভর্তি যুদ্ধের অভিজ্ঞতা নিয়ে একটা ডায়েরী লিখেছে, যেখানে আমাদের কথা উল্লেখ করেছে। শুনলাম সে নাকি এবার বুয়েটের সিএসই তে ভর্তি হয়েছে।
#
# পুরো সময় ধরে আমাদের একটা অবজারভেশন ছিল যে, সব স্টুডেন্টরা আসলে এই তিন মাসে এত নতুন কিছু শিখতে পারে না। যারা সারা বছর এডমিশন টেস্ট এর ধাঁচের প্রশ্ন সলভ করে না। তাই হঠাৎ করে তার কাছে সব কিছু অপরিচিত ও কঠিন মনে হয়।
# সর্বোপরি আমাদের মতে,
# "প্রস্তুতিটা ৩ মাসের নয়, ২ বছরের"।
#
# তাই আমরা সিদ্ধান্ত নিয়েছি, ইন্টার ফার্স্ট ইয়ার ও সেকেন্ড ইয়ার এর শিক্ষার্থীদের জন্যও আমাদের কার্যক্রম চালিয়ে যাওয়া উচিৎ
#
# তাই এখন আমাদের দরকার তোমাদের সাহায্য। হ্যাঁ, তুমি, যে কিনা আমাদের সাথে যোগ দিতে চাও আর ছোটদের সাহায্য করতে চাও। এইচ এস সি '১৭ ব্যাচের যারা এবার ভর্তিপরীক্ষা শেষ করে অলস সময় কাটাচ্ছ, তোমরা  চাইলেই বাসায় বসে ঢাকার বাইরের একজন সুবিধাবঞ্চিত মেধাবী জুনিওরকে সাহায্য করতে পার।  বিশ্বাস কর, সে কখনই তোমার সাহায্যের কথা ভুলতে পারবে না। আর তাছাড়া,  আমাদের থেকে ইন্টার এর পড়া এই মুহুর্তে তোমরা ভাল পার।
#
# যে কেউ চাইলেই আমাদের সাথে যোগ দিতে পার।
#
# আমরা তিনটি জিনিস এ ভলেন্টিয়ার চাচ্ছি।
# ১. ডিসাইন টিম:
# তুমি যদি মোটামোটি ডিসাইন এর কাজ পার, Powerpoint বা paint এ ডিসাইন করতে পার, তবে সহজেই তুমি আমাদের টিম এর অংশ হতে পার।
#
# ২. রেস্পন্স টিম:
#  এই টিম এর কাজ সবচেয়ে সহজ। প্রতিদিন আধা ঘন্টা সময় করে বিভিন্ন প্রশ্নের উত্তর দিতে হবে। যেহেতু জিনিস গুলো তোমার পড়ার মধ্যেই আছে, কাজেই সহজেই তুমি তা করতে পারবে।
#
# ৩. মোটিভেশন টিম:
# একজন ছাত্রের সবচেয়ে বেশি প্রয়োজন মোটিভেশন। সে জন্য ওদের জন্য কিছু মোটিভেশনাল লেখা চাচ্ছি আমরা।তুমি চাইলে সে কাজটিও করতে পার।
#
# আমাদের সাথে নিয়মিত না থাকতে পারলেও, তোমার যদি বলার মত কোন গল্প থাকে, নিজের ব্যক্তিগত কোন অভিজ্ঞতা থাকে, যা তোমার মনে হয় একটা ইন্টার পড়ুয়া ছাত্রের জানলে ভাল হবে, তবে আমাদের সেটা পাঠিয়ে দিতে পার। আমরা তা তোমার নামে পোস্ট করে দিতে পারি।
#
# ডিজিটাল এই যুগে কারো উপকার করার জন্য একটি কম্পিউটারই যথেষ্ট। শুধু ইচ্ছাটাই হল সবচেয়ে বড়।
#
# আবেদন ইচ্ছুকরা কমেন্টের ফর্মে আবেদন করো
#
#  সবাইকে শুভ কামনা :)
# time :   2017-11-30T16:54:54+0000
# id   : 3964403643573572_2095321650481790
#
#
# 124
#
# with a stick and his brain 😍
# time :   2017-11-27T08:54:19+0000
# id   : 3964403643573572_2087468787933743
#
#
# 125
#
# time :   2017-11-25T15:52:26+0000
# id   : 3964403643573572_2085097384837550
# length of the dictionary 2
# length of the data part 24
# 126
#
# "একাডেমিক প্রেশার এর কথা সবাই বলে, কিন্তু ফেসবুক ব্যবহার তো কেউ ছাড়ে না।
# বরং অনেক সময় ফেসবুকেই একাডেমিক প্রেশার নিয়ে ওয়াইন করে"
#  with Awsaf Alam Anindo Raashid Mahdi Sharmin Akther Purabi
# time :   2017-11-23T15:52:55+0000
# id   : 3964403643573572_2081665145180774
#
#
# 127
#
# মন খুলে কথা বলার মানুষ ঢাকায় পদার্পণ করেছে...
# বার্গারটা না উঁচিয়ে ধরলেই বোধহয় ভাল হত :v
# time :   2017-11-18T15:01:17+0000
# id   : 3964403643573572_2069632386384050
#
#
# 128
#
# বন্ধু ১:
#   এই শোন, আমরা যেই কম্পিটিশন টা করতেসি সেটার কালকে গ্রুমিং সেশন সকাল ৯টায়। সবার যেতে হবে না, টিম থেকে একজন গেলেই হবে। কেউ না গেলে disqualified করে দিবে।
#
# বন্ধু ২: কে যাবি?
#
# আমি: দোস্ত, আমার কালকে সকালে ৯ টায় ফ্যাকাল্টি ডিবেট আছে, আমি কোনভাবেই কাল যেতে পারব না। তোরা কেউ যা...
#
# বন্ধু ২: আমি যাইতে পারব না।
#
# বন্ধু ১: আমিও না।
#
# আমি: কেন? কি হইসে?
#
# বন্ধু ২: আরে আমার কালকে পড়া লাগবে।  লাস্ট সিটি অনেক কম পাইসি। এইটা ভাল করাই লাগবে।
#
# আমি : অনেক কম? :/  কত?
#
# বন্ধু ২:  ১৩।  মাত্র ১৩ (২০ এ) :(
#
# আমি : ওহ,  আচ্ছা। :3
#
# বন্ধু ২ : বন্ধু ১, তাহলে তুই যা।
#
# বন্ধু ১ : না,কালকে শুক্রবার,আমি বের হতে পারব না।
#
# আমি : কেন? শুক্রবারে কি সমস্যা?
#
# বন্ধু ১: ইয়ে মানে, আম্মু বের হতে মানা করসে শুক্রবারে....
#
# আমি : ওহ, আচ্ছা। :3
#
# বন্ধু ১: মুশি, তুই চলে যা। আর না পারলে বাদ দে ।
#
# আমি : আচ্ছা :3
# time :   2017-11-14T13:27:47+0000
# id   : 3964403643573572_2063854813628474
#
#
# 129
#
# two useful extensions.
# btw, this guy is funny :v
# time :   2017-11-14T12:48:11+0000
# id   : 3964403643573572_2063810710299551
#
#
# 130
#
# a wonderful gift from friends <3
# time :   2017-11-12T16:59:32+0000
# id   : 3964403643573572_2061389950541627
#
#
# 131
#
# time :   2017-11-12T06:45:01+0000
# id   : 3964403643573572_2060770577270231
#
#
# 132
#
# time :   2017-11-12T06:44:20+0000
# id   : 3964403643573572_2060769950603627
#
#
# 133
#
# time :   2017-11-12T06:39:56+0000
# id   : 3964403643573572_2060766120604010
#
#
# 134
#
# সাজেকে আর খাগড়াছড়ি। জীবনের প্রথম এত বড় ট্যুর দিলাম আমরা। অনেক কথাই লেখা যায়, শুধু মনে হয়েছে লাইফ গোল হবার মত ট্যুর ছিল।
# time :   2017-11-12T06:39:44+0000
# id   : 3964403643573572_2060772270603395
#
#
# 135
#
# time :   2017-11-12T06:39:28+0000
# id   : 3964403643573572_2060765857270703
#
#
# 136
#
# time :   2017-11-12T06:39:17+0000
# id   : 3964403643573572_2060765750604047
#
#
# 137
#
# time :   2017-11-12T06:39:02+0000
# id   : 3964403643573572_2060772270603395
#
#
# 138
#
# তোমাকে মনে পরবে
# যখনই জোছনা হাসে,
# তোমাকে মনে পরবে
# যখনই আকাশ ভেঙে বর্ষা কাঁদে!
# 😘😘😘
#
# when u have some fucked up friends who frapes u, then turns of notifications and hides the post from your timeline.... :v
# thanks to Arpon Paul for warning me about this lame frape.
#
# Sadia Tasnim and Ishtiaq Niloy, game on...
# time :   2017-11-12T06:38:00+0000
# id   : 3964403643573572_2060764423937513
#
#
# 139
#
# সাজেকে আর খাগড়াছড়ি। জীবনের প্রথম এত বড় ট্যুর দিলাম আমরা। অনেক কথাই লেখা যায়, শুধু মনে হয়েছে লাইফ গোল হবার মত ট্যুর ছিল।
# time :   2017-11-12T06:36:47+0000
# id   : 3964403643573572_2060772267270062
#
#
# 140
#
# শুভ জন্মদিন রিচাপু।
# সহজ সরল হাসিখুশি একটা মানুষ তুমি। মানুষকে অনেক ভাল অবজার্ভ কর। দেখা হলে এক মাইল দূর হতে হাসি দাও :v  ভাল লাগে ব্যাপারটা।
# 😁
# with Richa Dutta Rakhee
# time :   2017-11-11T13:49:57+0000
# id   : 3964403643573572_2059729114041044
#
#
# 141
#
# identify me.
# p.c. Naimul Arefin
# at sajek helipad
# time :   2017-11-10T18:04:41+0000
# id   : 3964403643573572_2058598010820821
#
#
# 142
#
# Got selected for the final rounds of tech_for_peace hackathon.
# 4 teams got selected from buet this year.
# keep us in prayer. we need all the luck we can get for the finals :3
# time :   2017-11-06T14:54:52+0000
# id   : 3964403643573572_2052965978050691
#
#
# 143
#
# remember kids,there is always hope for you.
# :3
# time :   2017-11-06T13:58:02+0000
# id   : 3964403643573572_2052909791389643
#
#
# 144
#
# p.c. শাশ্বত সৌম্য <3
# time :   2017-11-03T18:10:36+0000
# id   : 3964403643573572_2049170428430246
#
#
# 145
#
# সম্বিলিত পরীক্ষা পদ্ধতি নিয়ে আমার হোমপেজ এ বেশ কয়েকটা লেখা এসেছে। জাফর স্যার এর লেখায় তিনি বেশ সুন্দর করে এই পরীক্ষা পদ্ধতির পক্ষে যুক্তি দিয়েছেন। যারা অনেক সুন্দর করে গুছিয়ে লিখতে পারেন তাদের লেখা পড়লে আপনি সহজেই কনভিন্সড হয়ে যাবেন যে তারা যা বলছেন, একেবারে ঠিক বলছেন।
#
# সম্মিলিত পরীক্ষা পদ্ধতি হল, সকল বিশ্ববিদ্যালয় ও ইঞ্জিনিয়ারিং ইন্সটিটিউট গুলোর জন্য একটাই পরীক্ষা নেয়া, কিছুটা মেডিকেল এর মত। এছাড়া অনেক মডিফিকেশন রাখা যাবে।
#
# এর অনেকগুলা সুবিধার মধ্যে অন্যতম হল,ভর্তি পরীক্ষার সময়ের অমানবিক ধকল/হয়রানি বন্ধ করা।যাদের ৪-৫ জায়গায় পরীক্ষা দিতে হয় তারা প্রচন্ড ভোগান্তির মুখে পড়ে।
#
# এই পদ্ধতি নিয়ে আলোচনা শুরু করলেই প্রশ্নফাস এর প্রসঙ্গ চলে আসে। এর পক্ষে যারা আছে তারা মনে করে সবাই একত্রিত হয়ে পরীক্ষা নিলে প্রশ্ন ফাস এর মত ব্যাপার সহজেই ঠেকানো সম্ভব।আমিও এটা মেনে নিচ্ছি।হয়ত সম্ভব।
#
# কিন্তু আমরা একটা গুরুত্বপূর্ণ জিনিস ভুলে যাচ্ছি। প্রশ্ন ফাস হওয়াই ভর্তি  পরীক্ষা কার্যক্রম এর এক মাত্র অনিয়ম না।  আরেকটি ছোট কিন্তু ভয়াবহ লুপ হোল আছে এখানে। আর সেটা হল পরীক্ষার হলে একে অপরের নকল করা, প্রচলত ভাষায় বললে, "দেখাদেখি করা"।
#
# আমি নিশ্চিত হয়ে বলতে পারি,যদি ssc বা hsc পরীক্ষায় দেখাদেখি করার অবাধ সুযোগ করে না দেওয়া হত,তবে এ প্লাস এর সংখ্যা ৯০% কমে যেত।
#
# ঢাকার প্রতিটা কলেজে টেস্ট পরীক্ষায় এ+ পায় মাত্র কয়েকজন করে,এডমিশন টেস্ট এ পাশও করে মাত্র কয়েকজন। কিন্তু মাঝখানে hsc পরীক্ষায় সবাই এ+!!! কিভাবে? কোন যাদুকরী বলে এত মানুষ ভালো পরীক্ষা দেয়? মূলত অবাধে দেখাদেখি করার সু্যোগই এত ভাল রেসাল্ট এর মূল চাবিকাঠি।একজন পারলে তার চারপাশের সবাই পারে...
#
# এডমিশন টেস্ট এ এসব হয় না ভাবছেন? তাহলে আমার নিজের কাহিনীই বলি। আমার ঢাবি এর পরীক্ষার সিট পড়েছিল ইডেন কলেজে। বিশাল হল রূমের লাস্ট বেঞ্চে। গার্ড দেয়ার দায়িত্ব যাদের উপরে ছিল তারা একবারো পেছনেই আসেন নি। আমার চারপাশের সবাই ইচ্ছা মত দেখাদেখি করেছিল। আমি সেদিন কোনমতে খাতা ঢেকে না লিখলে,তাদের মধ্য হতেই কেউ একজন অনেক ভাল করে ফেলত।ঢাবি নিজেদের বিশ্ববিদ্যাএর বাইরে সিট ফালানোর কারনেই এটা সম্ভব হয়েছে।আমাদের সময় একি রকমের ঘটনা চুয়েটেও ঘটেছিল....
#
# সম্বিলিত পরীক্ষা পদ্ধতি তে আপনি দেশের সব জায়গায় ডেডিকেটেড হল নিয়ন্ত্রক পাবেন তার নিশ্চয়তা কি?
#
# ব্যাপারটা খুব সহজ, কোন এক প্রত্যন্ত অঞ্চলে একজন মেধাবী শিক্ষার্থী এর পাশে সিট পড়া অযোগ্য কেউ বুয়েটে ভর্তি হয়ে যাবে, এটা চিন্তা করলেই আমার গা গুলিয়ে আসে....
# time :   2017-11-03T14:41:49+0000
# id   : 3964403643573572_2048929985120957
#
#
# 146
#
# শুভ জন্মদিন Arpita দি।
# এভাবেই হাসতে হাসতে গড়াগড়ি খাও সবসময়,এই কামনা করি।
# time :   2017-11-02T07:24:28+0000
# id   : 3964403643573572_2047214228625866
#
#
# 147
#
# with Gifarie Tayeef Islam and  Mohammad Mostafa Raihan
# time :   2017-10-31T18:01:41+0000
# id   : 3964403643573572_2045144398832849
#
#
# 148
#
# বুয়েটের ছাত্রদের উপর ঢাকা বিশ্ববিদ্যালয় এর সোনার ছেলেদের অতর্কিত আক্রমণ।
# #repost
# #সত্য_সবাই_জানবে
# time :   2017-10-29T15:01:44+0000
# id   : 3964403643573572_2042191055794850
#
#
# 149
#
# ধাওয়া পাল্টা ধাওয়া নয়,অতর্কিত আক্রমণ...
# জানি এই ভিডিও দেখে কাউকেই ধরা হবে না,কিছুই হবে না...
# কিন্তু সবাই দেখুক তাদের আসল চেহারা,সত্য খবরটা ছড়িয়ে যাক সবার কাছে।
# সবাই কমেন্ট সেকশনে দেখেন...
# time :   2017-10-29T14:40:40+0000
# id   : 3964403643573572_2042166665797289
#
#
# length of the dictionary 2
# length of the data part 25
# 150
#
# although I hate the name "EEE" :3
# time :   2017-10-21T16:26:00+0000
# id   : 3964403643573572_2030952650252024
#
#
# 151
#
# happy birthday Nadia Anjum Antara
# 😁
# time :   2017-10-20T18:49:55+0000
# id   : 3964403643573572_2029864823694140
#
#
# 152
#
# "এই পৃথিবীতে সব কিছুই অসীম,শুধু সময়টাই সসীম। মানুষ কোটি কোটি টাকা কামাতে পারে,এইটার কোন লিমিট নাই,কিন্তু কেউ চাইলেই শত বছর বাঁচতে পারে না। তাই সময় খরচ করতে হবে হিসেব করে,মিতব্যয়ী হয়ে।"
# #classroom_philosophy
# time :   2017-10-17T17:21:17+0000
# id   : 3964403643573572_2025936394086983
#
#
# 153
#
# "আমি আজ পর্যন্ত যতগুলো ভার্সিটি গেসি,তার সব গুলাই বুয়েট থেকে বেশি সুন্দর"
# with Nafis Tahmid
#
# #iut
# time :   2017-10-14T17:31:23+0000
# id   : 3964403643573572_2022007514479871
#
#
# 154
#
# "আমার কাছে ১০ টাকা ভাংতি নাই,কিন্তু ৩০ টাকা ভাংতি আছে!!!"- ডাক্তারনি গিফারী
# :3
# time :   2017-10-12T17:08:23+0000
# id   : 3964403643573572_2019167614763861
#
#
# 155
#
# 4.46 pm
# time :   2017-10-08T18:17:47+0000
# id   : 3964403643573572_2014252091922080
#
#
# 156
#
# যা খুশি তা বলে দিয়ে,কথা শুনিয়ে দিয়ে বাক্যের শেষে একটা :p দিয়ে দিলেই বুঝি সাত খুন মাফ হয়ে যায়।
# আর প্রতিবাদ করলেই,
# "দোস্ত তুই এত খ্যাত কেন?একটা সার্কাজমও বুঝস না?"
# time :   2017-10-06T17:19:17+0000
# id   : 3964403643573572_2011576862189603
#
#
# 157
#
# -এত পারে কেমনে?কি খায় ওরা?
# -মারা খায়।
# -মানে?
# -আরে বুঝিস নাই? এগুলি কি একদিনে শিখসে? মারা খাইতে খাইতে শিখসে। অনেক জায়গায় হেরে এখন জেতা শিখসে।
# <3
#
# with Raashid Mahdi
# time :   2017-10-05T16:42:43+0000
# id   : 3964403643573572_2010206945659928
#
#
# 158
#
# স্যার ক্লাসে একটা প্রব্লেম সলভ করতে দিয়েছিলেন।
# সবার খাতা চেক করে এসে বললেন,
#
# "তোমাদের অনেকেরই কিছু ভুল হয়েছে।মজার কথা হল ভুলটা ধরিয়ে দেয়ার সাথে সাথে তুমিও বুঝতে পেরেছ কোথায়, কেন ভুল হয়েছে। কিন্তু কিছু করার নেই আসলে,কারন ভুল হয়ে গেছে।"
#
# #classroom_philosophy
# time :   2017-10-03T16:17:48+0000
# id   : 3964403643573572_2007676829246273
#
#
# 159
#
# বুয়েটে ক্লাস করা শুরু করার পর থেকেই প্রায়ই একটা জিনিস ফেস করি। সেটা হল কিছু অপরিচিত ও স্বল্প পরিচিত জুনিওরদের ম্যাসেজ।
#
#  তাদের বেশিরভাগ ম্যাসেজ সাধারনত, "ভাইয়া এই অংকটা করে দেন" থেকে শুরু করে "ভাইয়া আপনি দিনে কত ঘন্টা পড়তেন?" টাইপ প্রশ্নের মধ্যে থাকে।
#
#  শুধু আমি না,মোটামোটি সব ভার্সিটি পড়ুয়া ছাত্রছাত্রীই এইধরনের ক্ষুদেবার্তা পায়।অনেকে দেখি এগুলো নিয়ে ট্রলও বানায়,কেউ কেউ বিরক্ত হয়।
#
# ...
# id   : 3964403643573572_1333464123334217
#
#
# 311
#
# ok,so thats simple everyday me... :)
# p.c. Mir Shahriar Kamal
# time :   2016-04-29T15:56:37+0000
# id   : 3964403643573572_1317497311597565
#
#
# 312
#
# first day at autocad lab...
# hope I can keep the smile on for the rest of the season :)
# time :   2016-04-27T12:45:43+0000
# id   : 3964403643573572_1315715831775713
#
#
# 313
#
# EEE lab এ মারা খাওয়ার পর আমরা...
# don't get confused by the smile...
# selfie তোলার সময় মুখে auto হাসি চলে আসে। ....
# :p :) :p with Nadia Anjum Antara  শাশ্বত সৌম্য Adnan Al Islam Rohan
# time :   2016-04-23T18:18:23+0000
# id   : 3964403643573572_1312693968744566
#
#
# 314
#
# time :   2016-04-14T14:48:36+0000
# id   : 3964403643573572_1305683006112329
#
#
# 315
#
# classroom selfie....
#
# (n-1) rule. মেনে  class এ বসলেন রানা মাসুদ ভাই নিজেও।(দেখুন ভিডিও সহ :-D  :-P :-P  )
# time :   2016-03-27T14:55:57+0000
# id   : 3964403643573572_1288924491121514
#
#
# 316
#
# time :   2016-03-03T15:29:55+0000
# id   : 3964403643573572_1266412696706027
#
#
# 317
#
# at Dia Bari
# time :   2016-03-03T15:28:58+0000
# id   : 3964403643573572_1266411966706100
#
#
# 318
#
# dhanmondi lake...
# paddle boat...
# buddys...
# :)
# time :   2016-02-17T17:41:01+0000
# id   : 3964403643573572_1255410764472887
#
#
# 319
#
# My dearest friend Giferie is back in Dhaka...
# Screw valentines day,today is friendship day to me...
# time :   2016-02-14T14:31:16+0000
# id   : 3964403643573572_1253210494692914
#
#
# 320
#
# একুশে বই মেলায় আমরা...
# ছবি গতকাল এর। কালকেই দেওয়া উচিৎ ছিল ...
# থাক,কি আর যায় আসে ...
# আমরা আমরাই তো...
# afraim কালকে চলে যাবে ruet এ...
# ওকে অনেক miss করব।
# :)
# time :   2016-02-13T18:01:12+0000
# id   : 3964403643573572_1252680171412613
#
#
# 321
#
# Taka ashey bhaishsha, uraai thhaishsha!  B|
#
# #part3
# BTW:uprer kothata kamal likhse...ami na... :P
# time :   2016-01-10T15:04:05+0000
# id   : 3964403643573572_1230057270341570
#
#
# 322
#
# photo credit: Shamiul Hasan Rumman
# time :   2016-01-08T17:03:18+0000
# id   : 3964403643573572_1228774587136505
#
#
# 323
#
# exploring,making new friends at BUET
# time :   2016-01-08T17:02:36+0000
# id   : 3964403643573572_1228774067136557
# length of the dictionary 2
# length of the data part 25
# 324
#
# time :   2016-01-01T16:38:08+0000
# id   : 3964403643573572_1224075004273130
#
#
# 325
#
# time :   2016-01-01T16:37:14+0000
# id   : 3964403643573572_1224074734273157
#
#
# 326
#
# time :   2016-01-01T16:33:58+0000
# id   : 3964403643573572_1224073427606621
#
#
# 327
#
# time :   2016-01-01T16:32:43+0000
# id   : 3964403643573572_1224072984273332
#
#
# 328
#
# this day goes to cousins and vaigna-vagni s...
# had too much fun...
# taking selfies were obviously very difficult...
# these cuties just move too much!!!
# love u all ...
# time :   2015-12-25T16:42:22+0000
# id   : 3964403643573572_1218939434786687
#
#
# 329
#
# time :   2015-12-21T16:21:28+0000
# id   : 3964403643573572_1216158995064731
#
#
# 330
#
# somewhere in DU campus
# darun ekta din...
# Mehedi celeta baccai theke gelo...
# time :   2015-12-14T16:24:19+0000
# id   : 3964403643573572_1210911238922840
#
#
# 331
#
# awesome ghura ghuri...
# Dhanmondi Lake
# time :   2015-12-13T15:41:02+0000
# id   : 3964403643573572_1210319052315392
#
#
# 332
#
# time :   2015-12-10T14:54:48+0000
# id   : 3964403643573572_1208520255828605
#
#
# 333
#
# time :   2015-12-10T14:51:08+0000
# id   : 3964403643573572_1208518995828731
#
#
# 334
#
# courtesy Jahinul Anam Fayed
# time :   2015-11-11T17:39:55+0000
# id   : 3964403643573572_1191650777515553
#
#
# 335
#
# coutesy Mir Shahriar Kamal
# time :   2015-11-10T13:41:02+0000
# id   : 3964403643573572_1190990414248256
#
#
# 336
#
# বুয়েট এ rank ছিল 166
# আজকে DU এর result পেলাম
# rank 38    !!!!
# আমি নিজেই অবাক। পরীক্ষা ভাল হইসে বুঝেছিলাম কিন্ত এত ভাল হইসে বুঝি নাই।
# সবই Allah এর রহমত ।
# :)
# time :   2015-11-04T17:56:32+0000
# id   : 3964403643573572_1187579584589339
#
#
# 337
#
# time :   2014-10-29T15:28:21+0000
# id   : 3964403643573572_947269855286981
#
#
# 338
#
# আমি আর আপু...
# time :   2014-10-29T15:11:54+0000
# id   : 3964403643573572_947262815287685
#
#
# 339
#
# time :   2014-06-10T02:40:18+0000
# id   : 3964403643573572_859568004057167
#
#
# 340
#
# time :   2014-06-07T16:39:49+0000
# id   : 3964403643573572_858011020879532
#
#
# 341
#
# college er 1st year class shesh....bolte gele kicu bojhar agei 1st year shesh hoye gelo...college life ami sobche obak hoyeci manuser obisshasso poriborton dekhe...sotti manus khub druto palte jai...
# 1st year k summarize korte giye bolar moto kono story pai na...life is boring...clg,coaching,bondu der sathe bikal perea sondha hoa adda...aito...
# result allah er rohmote valo hoise (i couldn't have wanted more).ata dhore rakhai akhon bishal challenge...
# r baki?career?admission?honour?status?debate?valobasha?...kotha ektai...time nai...time nai...
# time :   2014-04-07T18:22:55+0000
# id   : 3964403643573572_820557947958173
#
#
# 342
#
# 5 bosor ager kotha...notun notun debate kora shiktesi...tuk-tak barowary  kore berai...club e bolte gele sakib kei chini...vaiader nam jani...emon somoy mgbsdc er jugpurti onusthan aslo...hisab kore dekhlan club ta amar theke 2-3 maser boro!jai hok...onusthane gea tou ami obak...atto atto boro vai asche!!!onek gula vaia k chinlam jara 2000 er agei school pass kore felse...akhon obosso obak hoi na...karon dekhi jei amar kono birthday mone thake na shei ami thik e 16 july tarikh ta nie excited feel kortesi...karon ektai...mgbsdc shudu kicu valo debater e toiri kore na boron proti bosor e mgbsdc poribar er kicu sodosso toiri kore,mgbsdc er jonno jader valobasaha   oporisim.....happy birthday
# time :   2013-07-15T18:18:05+0000
# id   : 3964403643573572_668003483213621
#
#
# 343
#
# kicu manus ase jader upor chaileo besi din rag kore thaka jai na....
# time :   2013-06-27T17:42:59+0000
# id   : 3964403643573572_658807924133177
#
#
# 344
#
# the moment of glory...with  অমিত প্রামানিক and Nafis Ferdous Sakib
# time :   2013-06-26T14:46:17+0000
# id   : 3964403643573572_658306564183313
#
#
# 345
#
# "রেখে গেলাম কিছু স্মৃতি শিশির ভেজা,
# মিলিয়ে জাক শিশিরের মত।
# গোধূলি বেলাই ভুল করে ডেকো না আমায়ে
# ভেবে নিও আমি এক সূর্যাস্তও।
# নিয়ে গেলাম কিছু ভেজা স্মৃতি,কিছু জয় পরাজয়
# থাক সেগুলো অবনিনব্ধ।
# এই পথে আমি খুঁজি আমাকে
# পথে গরি কত স্মৃতি,
# আগামীর তরে বিদায় জানাই আমি
# -সময়ের এর অতিথই"
# তনয় ভাইয়ের এই গানটা এখন আমার জীবনেরও অংশও। এখন বুঝি কারা "সময়ের অতিথই"... কেন তাদের বিদায় জানাতে হবে...বিদায় বন্ধুরা...
# time :   2013-06-25T18:40:01+0000
# id   : 3964403643573572_657930127554290
#
#
# 346
#
# onek chinta onek tension o jolpona kolpona sheshe "Dhaka city college" e vorti holam...hope it brings best results for me and helps me to be the best i can be...
# time :   2013-06-23T16:19:43+0000
# id   : 3964403643573572_656900714323898
#
#
# 347
#
# ajker dinta chorom katlo...gang nia gelam "novo theater"...5d movie dekhlam...oita tou chorom...tar pore gelam shamorik jadughore...oikhane tank er upre uthlam...rifel ,kaman r bangladesher bijoi sonod dekhlam...onek joss lagse...
# time :   2013-04-16T15:32:29+0000
# id   : 3964403643573572_622188547795115
#
#
# 348
#
# time :   2013-04-02T16:38:53+0000
# id   : 3964403643573572_359612534147180
#
#
# length of the dictionary 2
# length of the data part 23
# 349
#
# time :   2013-03-30T12:58:59+0000
# id   : 3964403643573572_614758045204832
#
#
# 350
#
# basay net nilam...ekhon asolei mone hocce pura prithibi amar hater muthoi....
# time :   2013-03-23T17:56:22+0000
# id   : 3964403643573572_611891135491523
#
#
# 351
#
# time :   2013-01-12T18:49:46+0000
# id   : 3964403643573572_125711867596958
#
#
# 352
#
# time :   2013-01-12T18:34:51+0000
# id   : 3964403643573572_319312851502856
#
#
# 353
#
# "mahmud-mushfique" er chorom performance e series jitlo bangladesh...!!!
# time :   2012-12-08T18:48:56+0000
# id   : 3964403643573572_554450601235577
#
#
# 354
#
# time :   2012-10-24T11:21:47+0000
# id   : 3964403643573572_534248219922482
#
#
# 355
#
# kokhono kokhono mne hoi abar jodi shei class -2 er life e fire jete partam.......jekhane amar roll cilo 30,amake kono sir-madam chinto na,beshi frnd cilo na,amar proti karo kono demand cilo na,kono expectation cilo na,kono daetto cilo na,kono chap cilo na.........
# time :   2012-06-03T16:32:00+0000
# id   : 3964403643573572_468248879855750
#
#
# 356
#
# prithibir 66% kaj e kore nari ra....cholo aj nari dibos e amra nari der somman korar protigga kori....
# time :   2012-03-08T04:57:05+0000
# id   : 3964403643573572_401345869879385
#
#
# 357
#
# ammu khub dukho kore bollo,"ahare,amar celeta kalo hoye jaitece...".amar uthe gelo hashi.....
# time :   2012-02-09T13:50:27+0000
# id   : 3964403643573572_380704825276823
#
#
# 358
#
# ajke bidding er por amar 2ta line mone porlo...
# 1-onek somoi 1ta cotto vul onek boro jhamela sristi kore.
# 2-onek somoy sobai jeta k vul mne kore tai sobai k chomok dey...
# ami jani na amar team er jonno konta thik hobe...ami chai 2 numbr ta...
# time :   2012-01-19T14:05:54+0000
# id   : 3964403643573572_363975790283060
#
#
# 359
#
# amader 1jn frend suicide korlo....keno?jani na...tbe eta jani j ami chai naj amonr karo sathe hok.
# time :   2012-01-12T14:14:55+0000
# id   : 3964403643573572_358778680802771
#
#
# 360
#
# mgbsdc arekta championship pailo.....onek valo lagtece.....
# time :   2011-12-30T14:09:18+0000
# id   : 3964403643573572_349616831718956
#
#
# 361
#
# santar jonno wait koro sobai....marry crismas
# time :   2011-12-24T18:01:21+0000
# id   : 3964403643573572_345491102131529
#
#
# 362
#
# ami vabsilam ai bonde poira fatai felbo.....kintu kicui porte parlam na....
# time :   2011-12-24T15:32:01+0000
# id   : 3964403643573572_345401485473824
#
#
# 363
#
# BIOLOGY BOI E PORCILAM "BASH" 19 PROKAR.....
# AJKE ENG 1ST PAPER EXM E SHEGULA CHOKHEO DEKHLAM
# time :   2011-12-09T12:58:54+0000
# id   : 3964403643573572_334629476551025
#
#
# 364
#
# ajker biology objective test ta amr kace "kbc" er moto lagse.....where u have 3 lifeline         1-ask a frnd(!)
# 2-expert advice(expert holo amr samner pola...)
# 3- "25-75" (it means gessing 1 from 4 ).....
# time :   2011-12-08T17:24:11+0000
# id   : 3964403643573572_334024569944849
#
#
# 365
#
# exam time:-its time to get serious....  playing time:-its time to have some fun...          sleeping time:-its time for dreams   facebook time:-its time to waist time......
# time :   2011-11-24T14:33:49+0000
# id   : 3964403643573572_324398850907421
#
#
# 366
#
# FB TE CRIME KORAR NOTUN IDEA:-JAKE ICCA TAKE GALI DIBO...PRE DORLE BOLBO-"AMAR ACCONT TA HAKE HOI GESILO....".
# time :   2011-11-13T11:17:59+0000
# id   : 3964403643573572_317218688292104
#
#
# 367
#
# life a 1st mixup dbt...tao abar ndc te...champion....it feels awesome...sob creadit dite chai amar mixup prtrn dr...sobbo nd jalal vai...thnx alot...
# time :   2011-10-31T15:19:09+0000
# id   : 3964403643573572_310339592313347
#
#
# 368
#
# statistics:-amar 100 frend er modde cele o meyer onupat 73:27....2.70:1.hahahah
# time :   2011-08-07T16:58:57+0000
# id   : 3964403643573572_266792496668057
#
#
# 369
#
# happy frendship day,jara frend tader jonno,abar jara "frend" na tadero jonno.
# time :   2011-08-07T16:45:23+0000
# id   : 3964403643573572_266787090001931
#
#
# 370
#
# yes...yes...hurrah...century...fb te akhon amr 100ta frnd
# time :   2011-08-05T14:26:50+0000
# id   : 3964403643573572_265727106774596
#
#
# 371
#
# kal bristir modde rikshai uthe1 ta advud jinis dekhlam...amr riksha oala vai er 1ta pa nai.tao tini beg na kre riksha chalachen...can u bealieve it???he taught me something...never give up,never serronder...
# time :   2011-07-22T17:16:20+0000
# id   : 3964403643573572_258649547482352
# length of the dictionary 2
# length of the data part 25
# 372
#
# amr class er samner sarir studnt der achorone ami purai depresd.tadr sarthoprta o hingsha dekhle mejaj kharap hoe jai...mne hoe amr sathe tadr na jani kotto bishal juddho....
# time :   2011-06-28T15:34:46+0000
# id   : 3964403643573572_246528572027783
#
#
# 373
#
# last 4 din ami khalar bsay cilam,khalato vai er bea cilo.no tensn,no porashona,no pain...just fun.but chle alam coz normal life a tou fire astei hobee......
# time :   2011-05-20T13:03:17+0000
# id   : 3964403643573572_227481343932506
#
#
# 374
#
# akhn khalar bsay...khalato vaiar bie...aj meyer holud.koto kaz!onek mja lagtece...:-)
# time :   2011-05-15T10:52:06+0000
# id   : 3964403643573572_225985927415381
#
#
# 375
#
# 1st term e g.math e 98,h.math e 70te 67,chestry te highest,physics o onek valo hoise.....but the fact is...ai exm er k6n6 dam nai....:-(
# time :   2011-05-15T10:49:04+0000
# id   : 3964403643573572_225985447415429
#
#
# 376
#
# sobai jokhon india r pakistan niya chillabe tokhn srilanka cup niya jabe...let us all chear fr srilanka
# time :   2011-03-26T18:36:35+0000
# id   : 3964403643573572_212331482114159
#
#
# 377
#
# aibr srilanka eee cup nibe.....
# time :   2011-03-26T18:20:45+0000
# id   : 3964403643573572_212327872114520
#
#
# 378
#
# ghum dhorseeeeeeee.......
# time :   2011-03-16T19:11:01+0000
# id   : 3964403643573572_209636862383621
#
#
# 379
#
# i hope we also win tomorrow just like bangladesh......
# time :   2011-03-11T16:52:44+0000
# id   : 3964403643573572_208176665862974
#
#
# 380
#
# bangladesh wins.....i love  bangladesh....
# time :   2011-03-11T16:51:47+0000
# id   : 3964403643573572_208176515862989
#
#
# 381
#
# from tomorrow the battle of buet begins....i ll give my best.lets see what happens....
# time :   2011-03-09T18:18:21+0000
# id   : 3964403643573572_207654379248536
#
#
# 382
#
# koyek din dhore amr luck kharap...kufa lagce...
# time :   2011-03-03T08:50:32+0000
# id   : 3964403643573572_206004152746892
#
#
# 383
#
# i hope bangladesh wins...but they r certainly not playing like a winner
# time :   2011-02-25T10:23:50+0000
# id   : 3964403643573572_204439326236708
#
#
# 384
#
# pray 3 mash pr 'vns fest' er maddome dbt e come back krlam...it was great,but if we win the final it will b greater...
# time :   2011-02-17T07:43:07+0000
# id   : 3964403643573572_202309683116339
#
#
# 385
#
# hay hay....bondher 1 mashe ki korlam?kiccu na....
# time :   2010-12-25T18:48:07+0000
# id   : 3964403643573572_179194845431883
#
#
# 386
#
# jsc....result....voi....r...matro...4din.
# time :   2010-12-25T18:46:17+0000
# id   : 3964403643573572_117885621613370
#
#
# 387
#
# axe doesnt work
# time :   2010-12-03T18:32:46+0000
# id   : 3964403643573572_180834391927349
#
#
# 388
#
# frnds barate chai....
# time :   2010-11-27T15:04:57+0000
# id   : 3964403643573572_175772482448225
#
#
# 389
#
# facebooke mashe 2 bar boshi
# time :   2010-11-27T15:00:20+0000
# id   : 3964403643573572_173427042676060
#
#
# 390
#
# akta dbt fest chai,plz...
# time :   2010-11-27T14:50:07+0000
# id   : 3964403643573572_170924269595095
#
#
# 391
#
# jsc shes but kono dbt nai,how discasting...kotto sopno dekci jsc dia koto dbt korbo,chance e pachi na...aaaa...
# time :   2010-11-27T14:38:39+0000
# id   : 3964403643573572_179512265398572
#
#
# 392
#
# dhur,vabcilam jsc exam dia onek moja korbo.but tensn er jonno kicui enjoy korte parci na.but main kotha hocce j--i am back...mgbsdc  sob jaigai champ. hobei...gusz i promise...
# time :   2010-11-14T18:07:19+0000
# id   : 3964403643573572_166881923333862
#
#
# 393
#
# sakib,tor 'aman' nam ta change kore ashol nam de.r nai le keo tr request accept korbe na.
# time :   2010-09-11T14:57:07+0000
# id   : 3964403643573572_152926568065465
#
#
# 394
#
# eid 1ta jatio festivle,akhn hindu,crisian o muslim..shobai palon kore.val val.
# time :   2010-09-11T14:54:11+0000
# id   : 3964403643573572_152079618147020
#
#
# 395
#
# sbai k basi eid mubarak
# time :   2010-09-11T14:51:49+0000
# id   : 3964403643573572_133839189995979
#
#
# 396
#
# hurrah amra idc te champ hoici!!!1st time!!!mgbs warriors(friends) der congrats.keep rocking guzs!
# time :   2010-09-03T13:23:18+0000
# id   : 3964403643573572_122889951097240
#
#
# length of the dictionary 2
# length of the data part 6
# 397
#
# oh!!!!!kotto din por  FB khullam!!!moja lagtece!mashe 1 bar fb dekhi but tao kivabe kivabe jen 20+ friends hoe gese!!!ami aro friends banate chai.
# time :   2010-09-03T13:14:54+0000
# id   : 3964403643573572_136310103079943
#
#
# 398
#
# we are in semi final of VNS hurrah:-):-):-)
# time :   2010-01-27T16:08:57+0000
# id   : 3964403643573572_276314892459
#
#
# 399
#
# we are in semi final of BNS hurrah
# time :   2010-01-27T15:58:23+0000
# id   : 3964403643573572_276417405457
#
#
# 400
#
# I have no friend
# time :   2009-10-28T14:00:54+0000
# id   : 3964403643573572_159241721733
#
#
# 401
#
# kono bondhu pai na
# time :   2009-08-07T14:52:27+0000
# id   : 3964403643573572_112586084579
#
#
# 402
#
# time :   1996-09-29T07:00:00+0000
# id   : 3964403643573572_903049063042394
#
#
# end of posts
